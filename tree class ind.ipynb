# %%
import pandas as pd
import numpy as np
col_names = [  'home/away','day/night','toss',  'batted first','win']

# %%
col = [  'home/away','day/night','toss',  'batted first','win']

# %%
dataset=pd.read_csv("C:\\Users\\Acer\\Downloads\\indm1.csv",names=col_names)

# %%
dataset
# Out:
#         home/away  day/night  toss  batted first  win
# NaN     home/away  day/night  toss  batted first  win
# NaN             0          0     0             0  win
#  0.0            1          1     1             1    0
#  1.0            1          2     1             2    0
#  2.0            1          2     1             2    0
#  3.0            1          2     2             1    1
#  4.0            1          2     1             2    0
#  5.0            1          2     2             1    1
#  6.0            1          2     2             2    1
#  7.0            1          2     1             2    0
#  8.0            1          2     2             1    0
#  9.0            1          2     1             2    1
#  10.0           1          2     1             1    1
#  11.0           1          1     1             1    0
#  12.0           1          1     1             1    1
#  13.0           1          1     1             2    1
#  14.0           1          2     2             2    1
#  15.0           1          2     1             1    1
#  16.0           1          2     2             2    0
#  17.0           1          1     2             2    1
#  18.0           1          2     2             2    0
#  19.0           1          2     1             2    1
#  20.0           1          2     1             1    0
#  21.0           1          2     2             2    0
#  22.0           1          1     2             2    1
#  23.0           1          1     1             1    0
#  24.0           1          1     1             1    0
#  25.0           1          1     1             1    0
#  26.0           1          1     2             2    0
#  27.0           1          2     2             1    0
# ...           ...        ...   ...           ...  ...
#  781.0          2          2     2             2    1
#  782.0          2          2     2             2    0
#  783.0          2          2     2             1    1
#  784.0          2          1     2             1    1
#  785.0          2          2     2             1    1
#  786.0          2          2     2             1    1
#  787.0          2          2     2             1    0
#  788.0          2          1     2             2    0
#  789.0          2          1     2             2    0
#  790.0          2          1     2             2    1
#  791.0          2          1     2             2    1
#  792.0          2          1     2             2    0
#  793.0          2          2     2             1    1
#  794.0          2          2     2             1    1
#  795.0          2          2     2             1    0
#  796.0          2          2     2             1    1
#  797.0          2          2     2             1    1
#  798.0          2          1     2             2    1
#  799.0          2          1     2             2    1
#  800.0          2          2     2             1    1
#  801.0          2          2     2             2    0
#  802.0          2          1     2             2    0
#  803.0          2          2     2             1    1
#  804.0          2          1     2             2    1
#  805.0          2          2     2             1    1
#  806.0          2          2     2             1    1
#  807.0          2          2     2             1    1
#  808.0          2          1     2             2    1
#  809.0          2          1     2             2    1
#  810.0          2          1     2             2    1
#
# [813 rows x 5 columns]

# %%
dataset['toss'],classes = pd.factorize(dataset['toss'])
dataset['batted first'],classes = pd.factorize(dataset['batted first'])
dataset['day/night'],classes = pd.factorize(dataset['day/night'])
dataset['home/away'],classes = pd.factorize(dataset['home/away'])

# %%
dataset
# Out:
#         home/away  day/night  toss  batted first  win
# NaN             0          0     0             0  win
# NaN             1          1     1             1  win
#  0.0            2          2     2             2    0
#  1.0            2          3     2             3    0
#  2.0            2          3     2             3    0
#  3.0            2          3     3             2    1
#  4.0            2          3     2             3    0
#  5.0            2          3     3             2    1
#  6.0            2          3     3             3    1
#  7.0            2          3     2             3    0
#  8.0            2          3     3             2    0
#  9.0            2          3     2             3    1
#  10.0           2          3     2             2    1
#  11.0           2          2     2             2    0
#  791.0          3          2     3             3    1
#  792.0          3          2     3             3    0
#  793.0          3          3     3             2    1
#  794.0          3          3     3             2    1
#  795.0          3          3     3             2    0
#  796.0          3          3     3             2    1
#  797.0          3          3     3             2    1
#  798.0          3          2     3             3    1
#  799.0          3          2     3             3    1
#  800.0          3          3     3             2    1
#  801.0          3          3     3             3    0
#  802.0          3          2     3             3    0
#  803.0          3          3     3             2    1
#  804.0          3          2     3             3    1
#  805.0          3          3     3             2    1
#  806.0          3          3     3             2    1
#  807.0          3          3     3             2    1
#  808.0          3          2     3             3    1
#  809.0          3          2     3             3    1
#  810.0          3          2     3             3    1
#
# [814 rows x 5 columns]

# %%
from __future__ import print_function

# %%
import csv
f=open("C:\\Users\\Acer\\Downloads\\indm1.csv")
csv_f = csv.reader(f)

# %%
for row in csv_f:
    print(row)
# Out:
# ['', 'home/away', 'day/night', 'toss', 'batted first', 'win']
# ['', '0', '0', '0', '0', 'win']
# ['', '1', '1', '1', '1', 'win']
# ['0.0', '2', '2', '2', '2', '0']
# ['1.0', '2', '3', '2', '3', '0']
# ['2.0', '2', '3', '2', '3', '0']
# ['3.0', '2', '3', '3', '2', '1']
# ['4.0', '2', '3', '2', '3', '0']
# ['5.0', '2', '3', '3', '2', '1']
# ['6.0', '2', '3', '3', '3', '1']
# ['7.0', '2', '3', '2', '3', '0']
# ['8.0', '2', '3', '3', '2', '0']
# ['9.0', '2', '3', '2', '3', '1']
# ['10.0', '2', '3', '2', '2', '1']
# ['11.0', '2', '2', '2', '2', '0']
# ['12.0', '2', '2', '2', '2', '1']
# ['13.0', '2', '2', '2', '3', '1']
# ['14.0', '2', '3', '3', '3', '1']
# ['15.0', '2', '3', '2', '2', '1']
# ['16.0', '2', '3', '3', '3', '0']
# ['17.0', '2', '2', '3', '3', '1']
# ['18.0', '2', '3', '3', '3', '0']
# ['19.0', '2', '3', '2', '3', '1']
# ['20.0', '2', '3', '2', '2', '0']
# ['21.0', '2', '3', '3', '3', '0']
# ['22.0', '2', '2', '3', '3', '1']
# ['23.0', '2', '2', '2', '2', '0']
# ['24.0', '2', '2', '2', '2', '0']
# ['25.0', '2', '2', '2', '2', '0']
# ['26.0', '2', '2', '3', '3', '0']
# ['27.0', '2', '3', '3', '2', '0']
# ['28.0', '2', '3', '2', '2', '0']
# ['29.0', '2', '3', '3', '3', '1']
# ['30.0', '2', '3', '3', '3', '0']
# ['31.0', '2', '3', '2', '2', '0']
# ['32.0', '2', '2', '2', '2', '1']
# ['33.0', '2', '3', '2', '2', '0']
# ['34.0', '2', '2', '2', '3', '1']
# ['35.0', '2', '2', '2', '2', '1']
# ['36.0', '2', '2', '3', '2', '0']
# ['37.0', '2', '2', '2', '2', '0']
# ['38.0', '2', '3', '3', '3', '0']
# ['39.0', '2', '2', '3', '2', '1']
# ['40.0', '2', '2', '2', '2', '1']
# ['41.0', '2', '2', '2', '2', '0']
# ['42.0', '2', '2', '2', '2', '1']
# ['43.0', '2', '2', '2', '2', '0']
# ['44.0', '2', '2', '3', '2', '1']
# ['179.0', '2', '3', '2', '3', '0']
# ['180.0', '3', '3', '2', '3', '0']
# ['181.0', '3', '3', '3', '2', '0']
# ['182.0', '3', '3', '3', '2', '1']
# ['183.0', '3', '3', '3', '3', '0']
# ['184.0', '3', '3', '3', '2', '0']
# ['185.0', '2', '3', '3', '2', '0']
# ['186.0', '3', '3', '3', '2', '0']
# ['187.0', '3', '3', '3', '3', '1']
# ['188.0', '3', '3', '2', '2', '0']
# ['189.0', '3', '3', '3', '2', '0']
# ['190.0', '3', '2', '3', '3', '1']
# ['191.0', '3', '3', '2', '3', '0']
# ['192.0', '3', '3', '3', '2', '0']
# ['193.0', '3', '3', '2', '2', '0']
# ['194.0', '2', '2', '3', '3', '1']
# ['195.0', '3', '3', '2', '3', '0']
# ['196.0', '3', '3', '3', '2', '0']
# ['197.0', '3', '3', '3', '3', '1']
# ['198.0', '3', '3', '3', '2', '1']
# ['199.0', '3', '3', '2', '3', '0']
# ['200.0', '3', '3', '3', '3', '1']
# ['201.0', '3', '3', '3', '2', '0']
# ['202.0', '3', '3', '2', '2', '0']
# ['203.0', '2', '2', '2', '2', '0']
# ['204.0', '3', '3', '2', '3', '1']
# ['205.0', '3', '3', '2', '2', '1']
# ['206.0', '3', '3', '2', '3', '1']
# ['207.0', '3', '3', '3', '2', '1']
# ['208.0', '3', '3', '2', '3', '0']
# ['209.0', '3', '2', '3', '3', '0']
# ['210.0', '3', '3', '2', '3', '1']
# ['211.0', '3', '3', '2', '2', '1']
# ['212.0', '3', '3', '3', '3', '0']
# ['213.0', '3', '3', '3', '2', '1']
# ['214.0', '3', '3', '3', '2', '1']
# ['215.0', '3', '3', '3', '2', '0']
# ['216.0', '3', '3', '3', '2', '0']
# ['217.0', '3', '3', '3', '2', '0']
# ['218.0', '3', '3', '3', '3', '0']
# ['219.0', '2', '3', '2', '2', '0']
# ['220.0', '2', '2', '3', '3', '0']
# ['221.0', '2', '2', '2', '2', '0']
# ['222.0', '3', '2', '2', '2', '0']
# ['223.0', '3', '2', '2', '2', '1']
# ['224.0', '3', '2', '3', '3', '0']
# ['225.0', '3', '3', '3', '3', '1']
# ['226.0', '3', '2', '3', '3', '0']
# ['227.0', '3', '3', '3', '2', '0']
# ['228.0', '3', '2', '3', '3', '1']
# ['229.0', '3', '2', '2', '2', '0']
# ['230.0', '3', '2', '2', '2', '1']
# ['231.0', '3', '2', '2', '2', '0']
# ['232.0', '3', '2', '2', '2', '0']
# ['233.0', '3', '3', '2', '2', '1']
# ['234.0', '3', '2', '2', '2', '0']
# ['235.0', '3', '3', '3', '2', '0']
# ['236.0', '3', '3', '2', '3', '0']
# ['237.0', '2', '2', '3', '3', '0']
# ['238.0', '2', '3', '3', '3', '1']
# ['239.0', '2', '3', '3', '3', '1']
# ['240.0', '2', '3', '2', '2', '0']
# ['241.0', '2', '3', '3', '3', '0']
# ['242.0', '2', '3', '3', '3', '0']
# ['243.0', '2', '3', '2', '2', '0']
# ['244.0', '3', '2', '3', '3', '0']
# ['245.0', '3', '2', '3', '3', '1']
# ['580.0', '3', '2', '2', '2', '0']
# ['581.0', '3', '3', '3', '3', '0']
# ['582.0', '3', '3', '2', '3', '0']
# ['583.0', '3', '2', '2', '3', '0']
# ['584.0', '3', '2', '2', '2', '0']
# ['585.0', '3', '3', '2', '2', '1']
# ['586.0', '3', '2', '3', '3', '0']
# ['587.0', '3', '3', '3', '3', '0']
# ['588.0', '3', '2', '3', '2', '0']
# ['589.0', '3', '2', '3', '3', '0']
# ['590.0', '3', '3', '3', '2', '0']
# ['591.0', '3', '2', '3', '2', '1']
# ['592.0', '3', '2', '2', '3', '1']
# ['593.0', '3', '3', '3', '2', '1']
# ['594.0', '3', '2', '3', '3', '0']
# ['595.0', '3', '3', '3', '2', '1']
# ['596.0', '3', '3', '3', '2', '1']
# ['597.0', '3', '3', '3', '2', '1']
# ['598.0', '3', '2', '2', '2', '0']
# ['599.0', '3', '2', '3', '3', '0']
# ['600.0', '3', '3', '3', '3', '0']
# ['601.0', '3', '3', '2', '2', '0']
# ['602.0', '3', '3', '2', '3', '1']
# ['603.0', '3', '3', '2', '3', '1']
# ['604.0', '3', '2', '3', '3', '1']
# ['605.0', '3', '2', '3', '2', '1']
# ['606.0', '3', '3', '3', '2', '0']
# ['607.0', '3', '2', '3', '2', '1']
# ['608.0', '3', '2', '2', '2', '1']
# ['609.0', '3', '3', '2', '3', '1']
# ['610.0', '3', '2', '3', '3', '0']
# ['611.0', '3', '3', '3', '2', '0']
# ['612.0', '3', '3', '3', '3', '1']
# ['613.0', '3', '3', '2', '2', '0']
# ['614.0', '3', '3', '2', '3', '1']
# ['615.0', '3', '3', '3', '2', '0']
# ['616.0', '3', '3', '2', '3', '0']
# ['617.0', '3', '2', '3', '3', '1']
# ['618.0', '3', '2', '3', '2', '1']
# ['619.0', '3', '3', '3', '3', '0']
# ['620.0', '3', '2', '2', '3', '0']
# ['621.0', '3', '2', '2', '3', '0']
# ['622.0', '3', '2', '2', '3', '0']
# ['623.0', '3', '2', '3', '3', '1']
# ['624.0', '3', '2', '3', '3', '1']
# ['625.0', '3', '3', '3', '2', '1']
# ['626.0', '3', '3', '3', '2', '1']
# ['627.0', '3', '3', '3', '2', '0']
# ['628.0', '3', '3', '2', '3', '0']
# ['629.0', '3', '2', '3', '3', '0']
# ['630.0', '3', '3', '3', '3', '0']
# ['631.0', '3', '2', '3', '2', '0']
# ['632.0', '3', '3', '3', '2', '0']
# ['633.0', '3', '3', '3', '2', '0']
# ['634.0', '3', '3', '3', '2', '0']
# ['635.0', '3', '3', '3', '3', '1']
# ['636.0', '3', '2', '3', '3', '0']
# ['637.0', '3', '3', '3', '2', '0']
# ['638.0', '3', '2', '3', '2', '1']
# ['639.0', '3', '2', '3', '3', '1']
# ['640.0', '3', '3', '3', '3', '0']
# ['641.0', '3', '2', '3', '3', '0']
# ['642.0', '3', '3', '2', '3', '0']
# ['643.0', '3', '3', '2', '2', '1']
# ['644.0', '3', '3', '3', '2', '1']
# ['645.0', '3', '3', '2', '2', '0']
# ['646.0', '3', '2', '2', '3', '0']
# ['713.0', '3', '2', '3', '3', '1']
# ['714.0', '3', '3', '2', '2', '0']
# ['715.0', '3', '3', '3', '3', '0']
# ['716.0', '3', '2', '2', '3', '0']
# ['717.0', '3', '3', '3', '2', '1']
# ['718.0', '3', '3', '2', '3', '0']
# ['719.0', '3', '2', '3', '3', '0']
# ['720.0', '3', '3', '3', '3', '0']
# ['721.0', '3', '3', '2', '2', '0']
# ['722.0', '3', '2', '2', '3', '0']
# ['723.0', '3', '3', '3', '2', '0']
# ['724.0', '3', '2', '2', '2', '1']
# ['725.0', '3', '3', '3', '2', '0']
# ['726.0', '3', '3', '2', '3', '1']
# ['727.0', '3', '3', '2', '3', '0']
# ['728.0', '3', '2', '3', '3', '1']
# ['729.0', '3', '2', '2', '2', '0']
# ['730.0', '3', '2', '3', '2', '1']
# ['731.0', '3', '2', '3', '3', '1']
# ['732.0', '3', '2', '2', '2', '0']
# ['733.0', '3', '2', '2', '2', '0']
# ['734.0', '3', '3', '2', '3', '1']
# ['735.0', '3', '2', '2', '2', '0']
# ['736.0', '3', '3', '2', '3', '0']
# ['737.0', '3', '3', '2', '3', '0']
# ['738.0', '3', '2', '2', '2', '0']
# ['739.0', '3', '3', '3', '3', '0']
# ['740.0', '3', '3', '3', '2', '1']
# ['741.0', '3', '3', '2', '3', '1']
# ['742.0', '3', '3', '2', '3', '1']
# ['743.0', '3', '2', '2', '2', '0']
# ['744.0', '3', '3', '3', '2', '1']
# ['745.0', '3', '3', '2', '3', '1']
# ['746.0', '3', '3', '2', '3', '1']
# ['747.0', '3', '3', '2', '3', '1']
# ['748.0', '3', '2', '3', '2', '0']
# ['749.0', '3', '2', '2', '2', '0']
# ['750.0', '3', '3', '2', '3', '1']
# ['751.0', '3', '2', '2', '3', '0']
# ['752.0', '3', '3', '2', '3', '1']
# ['753.0', '3', '2', '2', '2', '1']
# ['754.0', '3', '3', '2', '3', '0']
# ['755.0', '3', '2', '2', '2', '0']
# ['756.0', '3', '3', '2', '3', '1']
# ['757.0', '3', '3', '2', '3', '0']
# ['758.0', '3', '2', '2', '2', '1']
# ['759.0', '3', '2', '2', '2', '1']
# ['760.0', '3', '3', '2', '3', '1']
# ['761.0', '3', '3', '3', '2', '0']
# ['762.0', '3', '2', '3', '3', '1']
# ['763.0', '3', '2', '3', '3', '0']
# ['764.0', '3', '3', '3', '2', '0']
# ['765.0', '3', '2', '3', '3', '0']
# ['766.0', '3', '3', '3', '3', '0']
# ['767.0', '3', '3', '3', '3', '0']
# ['768.0', '3', '3', '3', '2', '0']
# ['769.0', '3', '3', '3', '3', '0']
# ['770.0', '3', '3', '3', '2', '1']
# ['771.0', '3', '3', '3', '2', '0']
# ['772.0', '3', '2', '3', '3', '0']
# ['773.0', '3', '3', '3', '2', '1']
# ['774.0', '3', '3', '3', '3', '0']
# ['775.0', '3', '3', '3', '3', '1']
# ['776.0', '3', '3', '3', '2', '1']
# ['777.0', '3', '3', '3', '2', '0']
# ['778.0', '3', '3', '3', '3', '0']
# ['779.0', '3', '2', '3', '3', '0']
# ['780.0', '3', '3', '3', '2', '0']
# ['781.0', '3', '3', '3', '3', '1']
# ['782.0', '3', '3', '3', '3', '0']
# ['783.0', '3', '3', '3', '2', '1']
# ['784.0', '3', '2', '3', '2', '1']
# ['785.0', '3', '3', '3', '2', '1']
# ['786.0', '3', '3', '3', '2', '1']
# ['787.0', '3', '3', '3', '2', '0']
# ['788.0', '3', '2', '3', '3', '0']
# ['789.0', '3', '2', '3', '3', '0']
# ['790.0', '3', '2', '3', '3', '1']
# ['791.0', '3', '2', '3', '3', '1']
# ['792.0', '3', '2', '3', '3', '0']
# ['793.0', '3', '3', '3', '2', '1']
# ['794.0', '3', '3', '3', '2', '1']
# ['795.0', '3', '3', '3', '2', '0']
# ['796.0', '3', '3', '3', '2', '1']
# ['797.0', '3', '3', '3', '2', '1']
# ['798.0', '3', '2', '3', '3', '1']
# ['799.0', '3', '2', '3', '3', '1']
# ['800.0', '3', '3', '3', '2', '1']
# ['801.0', '3', '3', '3', '3', '0']
# ['802.0', '3', '2', '3', '3', '0']
# ['803.0', '3', '3', '3', '2', '1']
# ['804.0', '3', '2', '3', '3', '1']
# ['805.0', '3', '3', '3', '2', '1']
# ['806.0', '3', '3', '3', '2', '1']
# ['807.0', '3', '3', '3', '2', '1']
# ['808.0', '3', '2', '3', '3', '1']
# ['809.0', '3', '2', '3', '3', '1']
# ['810.0', '3', '2', '3', '3', '1']

# %%
import csv

f=open("C:\\Users\\Acer\\Downloads\\indm1.csv")
csv_f = csv.reader(f)

training_set = []

for row in csv_f:
  training_set.append(row)

print(training_set)
# Out:
# [['', 'home/away', 'day/night', 'toss', 'batted first', 'win'], ['', '0', '0', '0', '0', 'win'], ['', '1', '1', '1', '1', 'win'], ['0.0', '2', '2', '2', '2', '0'], ['1.0', '2', '3', '2', '3', '0'], ['2.0', '2', '3', '2', '3', '0'], ['3.0', '2', '3', '3', '2', '1'], ['4.0', '2', '3', '2', '3', '0'], ['5.0', '2', '3', '3', '2', '1'], ['6.0', '2', '3', '3', '3', '1'], ['7.0', '2', '3', '2', '3', '0'], ['8.0', '2', '3', '3', '2', '0'], ['9.0', '2', '3', '2', '3', '1'], ['10.0', '2', '3', '2', '2', '1'], ['11.0', '2', '2', '2', '2', '0'], ['12.0', '2', '2', '2', '2', '1'], ['13.0', '2', '2', '2', '3', '1'], ['14.0', '2', '3', '3', '3', '1'], ['15.0', '2', '3', '2', '2', '1'], ['16.0', '2', '3', '3', '3', '0'], ['17.0', '2', '2', '3', '3', '1'], ['18.0', '2', '3', '3', '3', '0'], ['19.0', '2', '3', '2', '3', '1'], ['20.0', '2', '3', '2', '2', '0'], ['21.0', '2', '3', '3', '3', '0'], ['22.0', '2', '2', '3', '3', '1'], ['23.0', '2', '2', '2', '2', '0'], ['24.0', '2', '2', '2', '2', '0'], ['25.0', '2', '2', '2', '2', '0'], ['26.0', '2', '2', '3', '3', '0'], ['27.0', '2', '3', '3', '2', '0'], ['28.0', '2', '3', '2', '2', '0'], ['29.0', '2', '3', '3', '3', '1'], ['30.0
100.0', '3', '2', '3', '2', '1'], ['101.0', '3', '2', '3', '2', '1'], ['102.0', '3', '2', '3', '3', '1'], ['103.0', '3', '2', '3', '2', '1'], ['104.0', '3', '2', '3', '3', '1'], ['105.0', '3', '3', '3', '3', '1'], ['106.0', '3', '3', '2', '3', '1'], ['107.0', '3', '3', '3', '3', '1'], ['108.0', '2', '2', '2', '2', '1'], ['109.0', '3', '3', '3', '3', '0'], ['110.0', '3', '3',  ...

# %%
training_set = training_set[1:len(training_set)]

# %%
def class_counts(rows):
    """Counts the number of each type of example in a dataset."""
    counts = {}  # a dictionary of label -> count.
    for row in rows:
        # in our dataset format, the label is always the last column
        label = row[-1]
        if label not in counts:
            counts[label] = 0
        counts[label] += 1
    return counts

# %%
def is_numeric(value):
    """Test if a value is numeric."""
    return isinstance(value, int) or isinstance(value, float)

# %%
class Question:
    """A Question is used to partition a dataset.

    This class just records a 'column number' (e.g., 0 for Color) and a
    'column value' (e.g., Green). The 'match' method is used to compare
    the feature value in an example to the feature value stored in the
    question. See the demo below.
    """

    def __init__(self, column, value):
        self.column = column
        self.value = value

    def match(self, example):
        # Compare the feature value in an example to the
        # feature value in this question.
        val = example[self.column]
        if is_numeric(val):
            return val >= self.value
        else:
            return val == self.value

    def __repr__(self):
        # This is just a helper method to print
        # the question in a readable format.
        condition = "=="
        if is_numeric(self.value):
            condition = ">="
        return "Is %s %s %s?" % (
            col[self.column], condition, str(self.value))

# %%
q=Question(0,'0')

# %%
q
# Out:
# Is home/away == 0?

# %%
# Let's pick an example from the training set...
example = training_set[2]
# ... and see if it matches the question
q.match(example) # this will be true, since the first example is Green.
#######
# Out:
# False

# %%
training_set[1]
# Out:
# ['', '1', '1', '1', '1', 'win']

# %%
def partition(rows, question):
    """Partitions a dataset.

    For each row in the dataset, check if it matches the question. If
    so, add it to 'true rows', otherwise, add it to 'false rows'.
    """
    true_rows, false_rows = [], []
    for row in rows:
        if question.match(row):
            true_rows.append(row)
        else:
            false_rows.append(row)
    return true_rows, false_rows

# %%
#######
# Demo:
# Let's partition the training data based on whether rows are Red.
true_rows, false_rows = partition(training_set, Question(0, '0'))
# This will contain all the 'Red' rows.
true_rows
# Out:
# []

# %%
def gini(rows):
    """Calculate the Gini Impurity for a list of rows.

    There are a few different ways to do this, I thought this one was
    the most concise. See:
    https://en.wikipedia.org/wiki/Decision_tree_learning#Gini_impurity
    """
    counts = class_counts(rows)
    impurity = 1
    for lbl in counts:
        prob_of_lbl = counts[lbl] / float(len(rows))
        impurity -= prob_of_lbl**2
    return impurity

# %%
def info_gain(left, right, current_uncertainty):
    """Information Gain.

    The uncertainty of the starting node, minus the weighted impurity of
    two child nodes.
    """
    p = float(len(left)) / (len(left) + len(right))
    return current_uncertainty - p * gini(left) - (1 - p) * gini(right)

# %%
#######
# Demo:
# Calculate the uncertainy of our training data.
current_uncertainty = gini(training_set)
current_uncertainty
# Out:
# 0.5017239840295082

# %%
true_rows, false_rows = partition(training_set, Question(1, '0'))
info_gain(true_rows, false_rows, current_uncertainty)
# Out:
# 0.0018391083334605707

# %%
true_rows, false_rows = partition(training_set, Question(0,'0'))
info_gain(true_rows, false_rows, current_uncertainty)
# Out:
# 0.0

# %%
true_rows, false_rows = partition(training_set, Question(2,'0'))
info_gain(true_rows, false_rows, current_uncertainty)
# Out:
# 0.0018391083334605707

# %%
true_rows, false_rows = partition(training_set, Question(3,'0'))
info_gain(true_rows, false_rows, current_uncertainty)
# Out:
# 0.0018391083334605707

# %%
true_rows, false_rows = partition(training_set, Question(3,'0'))

# %%
true_rows
# Out:
# [['', '0', '0', '0', '0', 'win']]

# %%
false_rows
# Out:
# [['', '1', '1', '1', '1', 'win'],
#  ['0.0', '2', '2', '2', '2', '0'],
#  ['1.0', '2', '3', '2', '3', '0'],
#  ['2.0', '2', '3', '2', '3', '0'],
#  ['3.0', '2', '3', '3', '2', '1'],
#  ['4.0', '2', '3', '2', '3', '0'],
#  ['5.0', '2', '3', '3', '2', '1'],
#  ['6.0', '2', '3', '3', '3', '1'],
#  ['7.0', '2', '3', '2', '3', '0'],
#  ['8.0', '2', '3', '3', '2', '0'],
#  ['9.0', '2', '3', '2', '3', '1'],
#  ['10.0', '2', '3', '2', '2', '1'],
#  ['11.0', '2', '2', '2', '2', '0'],
#  ['12.0', '2', '2', '2', '2', '1'],
#  ['13.0', '2', '2', '2', '3', '1'],
#  ['14.0', '2', '3', '3', '3', '1'],
#  ['15.0', '2', '3', '2', '2', '1'],
#  ['16.0', '2', '3', '3', '3', '0'],
#  ['17.0', '2', '2', '3', '3', '1'],
#  ['18.0', '2', '3', '3', '3', '0'],
#  ['19.0', '2', '3', '2', '3', '1'],
#  ['20.0', '2', '3', '2', '2', '0'],
#  ['21.0', '2', '3', '3', '3', '0'],
#  ['22.0', '2', '2', '3', '3', '1'],
#  ['23.0', '2', '2', '2', '2', '0'],
#  ['24.0', '2', '2', '2', '2', '0'],
#  ['25.0', '2', '2', '2', '2', '0'],
#  ['26.0', '2', '2', '3', '3', '0'],
#  ['27.0', '2', '3', '3', '2', '0'],
#  ['28.0', '2', '3', '2', '2', '0'],
#  ['29.0', '2', '3', '3', '3', '1'],
#  ['30.0', '2', '3', '3', '3', '0'],
#  ['31.0', '2', '3', '2', '2', '0'],
#  ['32.0', '2', '2', '2', '2', '1'],
#  ['33.0', '2', '3', '2', '2', '0'],
#  ['34.0', '2', '2', '2', '3', '1'],
#  ['35.0', '2', '2', '2', '2', '1'],
#  ['36.0', '2', '2', '3', '2', '0'],
#  ['37.0', '2', '2', '2', '2', '0'],
#  ['38.0', '2', '3', '3', '3', '0'],
#  ['39.0', '2', '2', '3', '2', '1'],
#  ['40.0', '2', '2', '2', '2', '1'],
#  ['41.0', '2', '2', '2', '2', '0'],
#  ['42.0', '2', '2', '2', '2', '1'],
#  ['43.0', '2', '2', '2', '2', '0'],
#  ['44.0', '2', '2', '3', '2', '1'],
#  ['45.0', '2', '2', '2', '3', '1'],
#  ['46.0', '2', '3', '2', '2', '1'],
#  ['47.0', '2', '2', '3', '2', '1'],
#  ['48.0', '2', '2', '2', '2', '1'],
#  ['49.0', '2', '3', '2', '3', '0'],
#  ['50.0', '2', '3', '3', '2', '1'],
#  ['51.0', '2', '3', '3', '2', '1'],
#  ['52.0', '2', '3', '2', '3', '0'],
#  ['53.0', '2', '3', '2', '2', '0'],
#  ['54.0', '2', '3', '2', '3', '0'],
#  ['55.0', '2', '3', '3', '2', '1'],
#  ['56.0', '2', '3', '3', '2', '0'],
#  ['57.0', '2', '3', '3', '2', '0'],
#  ['58.0', '2', '3', '3', '2', '1'],
#  ['59.0', '2', '3', '2', '3', '0'],
#  ['60.0', '2', '3', '3', '2', '1'],
#  ['61.0', '2', '3', '3', '2', '0'],
#  ['62.0', '2', '3', '2', '3', '0'],
#  ['63.0', '2', '3', '3', '2', '1'],
#  ['64.0', '2', '3', '3', '2', '1'],
#  ['65.0', '2', '2', '3', '3', '1'],
#  ['66.0', '2', '3', '3', '2', '0'],
#  ['67.0', '2', '2', '2', '2', '1'],
#  ['68.0', '2', '3', '2', '2', '1'],
#  ['69.0', '2', '3', '3', '2', '0'],
#  ['70.0', '2', '2', '2', '2', '0'],
#  ['71.0', '2', '3', '2', '3', '1'],
#  ['72.0', '2', '3', '2', '2', '1'],
#  ['73.0', '2', '3', '3', '3', '1'],
#  ['74.0', '2', '3', '2', '2', '1'],
#  ['75.0', '2', '3', '3', '3', '0'],
#  ['76.0', '2', '3', '3', '2', '1'],
#  ['77.0', '2', '2', '3', '2', '1'],
#  ['78.0', '2', '3', '2', '3', '1'],
#  ['79.0', '2', '3', '3', '3', '1'],
#  ['80.0', '2', '3', '2', '3', '1'],
#  ['81.0', '2', '2', '2', '3', '1'],
#  ['82.0', '2', '2', '3', '2', '1'],
#  ['83.0', '2', '2', '3', '3', '1'],
#  ['84.0', '2', '2', '2', '2', '1'],
#  ['85.0', '2', '2', '2', '2', '1'],
#  ['86.0', '2', '2', '2', '2', '1'],
#  ['87.0', '2', '2', '2', '3', '1'],
#  ['88.0', '2', '2', '2', '2', '0'],
#  ['89.0', '2', '2', '3', '3', '1'],
#  ['90.0', '2', '2', '3', '2', '1'],
#  ['91.0', '2', '2', '3', '2', '1'],
#  ['92.0', '2', '3', '2', '3', '0'],
#  ['93.0', '2', '2', '3', '2', '1'],
#  ['94.0', '3', '2', '2', '2', '1'],
#  ['95.0', '2', '3', '3', '2', '1'],
#  ['96.0', '2', '2', '3', '2', '1'],
#  ['97.0', '2', '2', '3', '2', '1'],
#  ['98.0', '2', '2', '3', '2', '1'],
#  ['99.0', '3', '3', '3', '3', '1'],
#  ['100.0', '3', '2', '3', '2', '1'],
#  ['101.0', '3', '2', '3', '2', '1'],
#  ['102.0', '3', '2', '3', '3', '1'],
#  ['103.0', '3', '2', '3', '2', '1'],
#  ['104.0', '3', '2', '3', '3', '1'],
#  ['105.0', '3', '3', '3', '3', '1'],
#  ['106.0', '3', '3', '2', '3', '1'],
#  ['107.0', '3', '3', '3', '3', '1'],
#  ['108.0', '2', '2', '2', '2', '1'],
#  ['109.0', '3', '3', '3', '3', '0'],
#  ['110.0', '3', '3', '2', '3', '0'],
#  ['111.0', '3', '3', '3', '3', '1'],
#  ['112.0', '3', '3', '3', '3', '0'],
#  ['113.0', '3', '3', '3', '3', '1'],
#  ['114.0', '3', '3', '2', '3', '0'],
#  ['115.0', '3', '3', '3', '2', '0'],
#  ['116.0', '3', '2', '3', '2', '1'],
#  ['117.0', '3', '3', '3', '2', '1'],
#  ['118.0', '3', '3', '2', '3', '0'],
#  ['119.0', '3', '2', '2', '3', '0'],
#  ['120.0', '3', '3', '3', '2', '1'],
#  ['121.0', '3', '3', '2', '3', '1'],
#  ['122.0', '3', '3', '3', '2', '1'],
#  ['123.0', '2', '3', '2', '3', '1'],
#  ['124.0', '2', '3', '2', '2', '1'],
#  ['125.0', '3', '3', '2', '3', '1'],
#  ['126.0', '3', '3', '3', '3', '1'],
#  ['127.0', '2', '3', '3', '2', '1'],
#  ['128.0', '2', '3', '2', '2', '1'],
#  ['129.0', '2', '3', '2', '3', '1'],
#  ['130.0', '2', '3', '2', '2', '1'],
#  ['131.0', '2', '3', '2', '2', '1'],
#  ['132.0', '2', '3', '3', '3', '1'],
#  ['133.0', '2', '3', '2', '3', '0'],
#  ['134.0', '2', '3', '3', '2', '1'],
#  ['135.0', '2', '3', '3', '2', '1'],
#  ['136.0', '2', '3', '3', '2', '0'],
#  ['137.0', '2', '3', '3', '2', '1'],
#  ['138.0', '2', '2', '2', '2', '1'],
#  ['139.0', '3', '2', '3', '3', '1'],
#  ['140.0', '3', '2', '3', '3', '0'],
#  ['141.0', '3', '3', '3', '3', '0'],
#  ['142.0', '2', '3', '2', '2', '0'],
#  ['143.0', '2', '3', '3', '3', '1'],
#  ['144.0', '2', '3', '3', '3', '1'],
#  ['145.0', '2', '3', '3', '2', '0'],
#  ['146.0', '2', '3', '2', '2', '1'],
#  ['147.0', '3', '3', '2', '3', '0'],
#  ['148.0', '3', '2', '2', '2', '0'],
#  ['149.0', '3', '3', '3', '2', '0'],
#  ['150.0', '3', '3', '2', '2', '1'],
#  ['151.0', '3', '3', '3', '2', '1'],
#  ['152.0', '2', '2', '3', '3', '0'],
#  ['153.0', '2', '2', '3', '3', '1'],
#  ['154.0', '3', '3', '2', '2', '0'],
#  ['155.0', '3', '3', '2', '2', '1'],
#  ['156.0', '3', '3', '3', '3', '0'],
#  ['157.0', '3', '2', '2', '2', '1'],
#  ['158.0', '3', '2', '2', '2', '0'],
#  ['159.0', '3', '2', '3', '3', '1'],
#  ['160.0', '2', '3', '2', '3', '1'],
#  ['161.0', '2', '2', '3', '2', '1'],
#  ['162.0', '2', '3', '3', '2', '1'],
#  ['163.0', '2', '2', '3', '2', '1'],
#  ['164.0', '2', '2', '2', '2', '1'],
#  ['165.0', '2', '3', '3', '2', '1'],
#  ['166.0', '2', '3', '3', '2', '1'],
#  ['167.0', '3', '3', '3', '3', '1'],
#  ['168.0', '3', '2', '2', '2', '1'],
#  ['169.0', '3', '2', '2', '2', '1'],
#  ['170.0', '3', '3', '2', '3', '1'],
#  ['171.0', '3', '3', '3', '2', '0'],
#  ['172.0', '3', '3', '2', '3', '0'],
#  ['173.0', '3', '3', '2', '3', '0'],
#  ['174.0', '2', '3', '2', '3', '0'],
#  ['175.0', '2', '3', '2', '3', '0'],
#  ['176.0', '2', '3', '2', '2', '1'],
#  ['177.0', '2', '3', '3', '3', '0'],
#  ['178.0', '2', '3', '3', '2', '0'],
#  ['179.0', '2', '3', '2', '3', '0'],
#  ['180.0', '3', '3', '2', '3', '0'],
#  ['181.0', '3', '3', '3', '2', '0'],
#  ['182.0', '3', '3', '3', '2', '1'],
#  ['183.0', '3', '3', '3', '3', '0'],
#  ['184.0', '3', '3', '3', '2', '0'],
#  ['185.0', '2', '3', '3', '2', '0'],
#  ['186.0', '3', '3', '3', '2', '0'],
#  ['187.0', '3', '3', '3', '3', '1'],
#  ['188.0', '3', '3', '2', '2', '0'],
#  ['189.0', '3', '3', '3', '2', '0'],
#  ['190.0', '3', '2', '3', '3', '1'],
#  ['191.0', '3', '3', '2', '3', '0'],
#  ['192.0', '3', '3', '3', '2', '0'],
#  ['193.0', '3', '3', '2', '2', '0'],
#  ['194.0', '2', '2', '3', '3', '1'],
#  ['195.0', '3', '3', '2', '3', '0'],
#  ['196.0', '3', '3', '3', '2', '0'],
#  ['197.0', '3', '3', '3', '3', '1'],
#  ['198.0', '3', '3', '3', '2', '1'],
#  ['199.0', '3', '3', '2', '3', '0'],
#  ['200.0', '3', '3', '3', '3', '1'],
#  ['201.0', '3', '3', '3', '2', '0'],
#  ['202.0', '3', '3', '2', '2', '0'],
#  ['203.0', '2', '2', '2', '2', '0'],
#  ['204.0', '3', '3', '2', '3', '1'],
#  ['205.0', '3', '3', '2', '2', '1'],
#  ['206.0', '3', '3', '2', '3', '1'],
#  ['207.0', '3', '3', '3', '2', '1'],
#  ['208.0', '3', '3', '2', '3', '0'],
#  ['209.0', '3', '2', '3', '3', '0'],
#  ['210.0', '3', '3', '2', '3', '1'],
#  ['211.0', '3', '3', '2', '2', '1'],
#  ['212.0', '3', '3', '3', '3', '0'],
#  ['213.0', '3', '3', '3', '2', '1'],
#  ['214.0', '3', '3', '3', '2', '1'],
#  ['215.0', '3', '3', '3', '2', '0'],
#  ['216.0', '3', '3', '3', '2', '0'],
#  ['217.0', '3', '3', '3', '2', '0'],
#  ['218.0', '3', '3', '3', '3', '0'],
#  ['219.0', '2', '3', '2', '2', '0'],
#  ['220.0', '2', '2', '3', '3', '0'],
#  ['221.0', '2', '2', '2', '2', '0'],
#  ['222.0', '3', '2', '2', '2', '0'],
#  ['223.0', '3', '2', '2', '2', '1'],
#  ['224.0', '3', '2', '3', '3', '0'],
#  ['225.0', '3', '3', '3', '3', '1'],
#  ['226.0', '3', '2', '3', '3', '0'],
#  ['227.0', '3', '3', '3', '2', '0'],
#  ['228.0', '3', '2', '3', '3', '1'],
#  ['229.0', '3', '2', '2', '2', '0'],
#  ['230.0', '3', '2', '2', '2', '1'],
#  ['231.0', '3', '2', '2', '2', '0'],
#  ['232.0', '3', '2', '2', '2', '0'],
#  ['233.0', '3', '3', '2', '2', '1'],
#  ['234.0', '3', '2', '2', '2', '0'],
#  ['235.0', '3', '3', '3', '2', '0'],
#  ['236.0', '3', '3', '2', '3', '0'],
#  ['237.0', '2', '2', '3', '3', '0'],
#  ['238.0', '2', '3', '3', '3', '1'],
#  ['239.0', '2', '3', '3', '3', '1'],
#  ['240.0', '2', '3', '2', '2', '0'],
#  ['241.0', '2', '3', '3', '3', '0'],
#  ['242.0', '2', '3', '3', '3', '0'],
#  ['243.0', '2', '3', '2', '2', '0'],
#  ['244.0', '3', '2', '3', '3', '0'],
#  ['245.0', '3', '2', '3', '3', '1'],
#  ['246.0', '2', '3', '2', '2', '1'],
#  ['247.0', '2', '2', '3', '3', '0'],
#  ['248.0', '2', '3', '2', '3', '1'],
#  ['249.0', '2', '2', '2', '2', '1'],
#  ['250.0', '2', '2', '3', '2', '0'],
#  ['251.0', '3', '2', '3', '3', '1'],
#  ['252.0', '3', '2', '2', '2', '0'],
#  ['253.0', '3', '2', '2', '2', '0'],
#  ['254.0', '3', '2', '2', '2', '1'],
#  ['255.0', '2', '2', '3', '3', '1'],
#  ['256.0', '3', '2', '2', '2', '1'],
#  ['257.0', '2', '3', '2', '2', '0'],
#  ['258.0', '2', '2', '3', '2', '0'],
#  ['259.0', '2', '2', '3', '3', '1'],
#  ['260.0', '3', '3', '3', '2', '1'],
#  ['261.0', '3', '2', '2', '3', '0'],
#  ['262.0', '3', '2', '3', '3', '1'],
#  ['263.0', '2', '3', '3', '2', '1'],
#  ['264.0', '2', '3', '2', '3', '1'],
#  ['265.0', '2', '2', '3', '3', '0'],
#  ['266.0', '3', '3', '2', '3', '0'],
#  ['267.0', '2', '3', '2', '3', '1'],
#  ['268.0', '2', '2', '3', '3', '1'],
#  ['269.0', '3', '3', '2', '2', '0'],
#  ['270.0', '3', '3', '2', '2', '0'],
#  ['271.0', '3', '3', '3', '3', '0'],
#  ['272.0', '3', '3', '2', '2', '0'],
#  ['273.0', '2', '2', '2', '2', '0'],
#  ['274.0', '2', '3', '3', '2', '0'],
#  ['275.0', '2', '3', '3', '3', '0'],
#  ['276.0', '2', '2', '3', '3', '1'],
#  ['277.0', '2', '2', '3', '3', '1'],
#  ['278.0', '3', '3', '3', '3', '0'],
#  ['279.0', '3', '3', '2', '2', '1'],
#  ['280.0', '3', '3', '3', '2', '0'],
#  ['281.0', '2', '3', '2', '2', '1'],
#  ['282.0', '2', '3', '2', '2', '1'],
#  ['283.0', '2', '3', '2', '3', '0'],
#  ['284.0', '2', '3', '2', '2', '1'],
#  ['285.0', '2', '3', '3', '2', '0'],
#  ['286.0', '3', '2', '3', '3', '0'],
#  ['287.0', '3', '2', '3', '3', '0'],
#  ['288.0', '3', '3', '3', '3', '1'],
#  ['289.0', '3', '2', '3', '3', '1'],
#  ['290.0', '3', '2', '3', '3', '1'],
#  ['291.0', '3', '2', '3', '3', '0'],
#  ['292.0', '2', '3', '2', '3', '0'],
#  ['293.0', '2', '2', '3', '2', '1'],
#  ['294.0', '2', '2', '2', '3', '0'],
#  ['295.0', '2', '2', '3', '2', '1'],
#  ['296.0', '3', '3', '2', '3', '0'],
#  ['297.0', '3', '3', '3', '2', '1'],
#  ['298.0', '3', '3', '3', '2', '1'],
#  ['299.0', '2', '2', '2', '3', '1'],
#  ['300.0', '2', '2', '3', '3', '1'],
#  ['301.0', '2', '2', '2', '2', '0'],
#  ['302.0', '2', '2', '3', '3', '0'],
#  ['303.0', '3', '3', '2', '3', '1'],
#  ['304.0', '3', '2', '3', '3', '1'],
#  ['305.0', '2', '3', '2', '2', '0'],
#  ['306.0', '2', '2', '3', '3', '1'],
#  ['307.0', '2', '2', '2', '2', '0'],
#  ['308.0', '2', '2', '3', '3', '1'],
#  ['309.0', '2', '2', '2', '2', '0'],
#  ['310.0', '3', '3', '3', '2', '0'],
#  ['311.0', '2', '3', '2', '3', '1'],
#  ['312.0', '2', '3', '2', '2', '1'],
#  ['313.0', '2', '3', '2', '2', '1'],
#  ['314.0', '3', '3', '3', '2', '1'],
#  ['315.0', '3', '3', '3', '2', '1'],
#  ['316.0', '3', '3', '3', '2', '1'],
#  ['317.0', '2', '3', '3', '2', '0'],
#  ['318.0', '2', '3', '3', '2', '1'],
#  ['319.0', '2', '3', '3', '2', '1'],
#  ['320.0', '2', '3', '2', '3', '1'],
#  ['321.0', '2', '3', '2', '3', '1'],
#  ['322.0', '3', '3', '2', '3', '1'],
#  ['323.0', '3', '3', '3', '2', '0'],
#  ['324.0', '3', '3', '3', '2', '1'],
#  ['325.0', '2', '3', '3', '3', '1'],
#  ['326.0', '3', '3', '2', '3', '0'],
#  ['327.0', '2', '3', '2', '3', '1'],
#  ['328.0', '2', '3', '3', '2', '1'],
#  ['329.0', '2', '3', '3', '3', '0'],
#  ['330.0', '2', '3', '2', '2', '0'],
#  ['331.0', '2', '3', '3', '2', '1'],
#  ['332.0', '2', '3', '3', '2', '1'],
#  ['333.0', '2', '3', '2', '3', '1'],
#  ['334.0', '2', '3', '3', '2', '1'],
#  ['335.0', '2', '3', '2', '3', '0'],
#  ['336.0', '3', '3', '2', '2', '1'],
#  ['337.0', '3', '3', '3', '2', '1'],
#  ['338.0', '2', '3', '2', '3', '0'],
#  ['339.0', '3', '3', '3', '3', '1'],
#  ['340.0', '2', '2', '3', '3', '0'],
#  ['341.0', '2', '3', '3', '2', '1'],
#  ['342.0', '2', '3', '3', '3', '0'],
#  ['343.0', '3', '2', '3', '2', '1'],
#  ['344.0', '3', '2', '2', '3', '1'],
#  ['345.0', '2', '3', '2', '3', '1'],
#  ['346.0', '2', '3', '2', '3', '1'],
#  ['347.0', '3', '3', '2', '3', '1'],
#  ['348.0', '3', '2', '2', '2', '0'],
#  ['349.0', '3', '2', '3', '3', '0'],
#  ['350.0', '3', '2', '3', '2', '0'],
#  ['351.0', '3', '2', '2', '2', '0'],
#  ['352.0', '3', '3', '2', '2', '1'],
#  ['353.0', '3', '3', '3', '2', '1'],
#  ['354.0', '3', '2', '3', '3', '1'],
#  ['355.0', '3', '3', '2', '3', '1'],
#  ['356.0', '2', '3', '3', '3', '1'],
#  ['357.0', '2', '2', '3', '2', '1'],
#  ['358.0', '2', '3', '2', '2', '1'],
#  ['359.0', '2', '3', '3', '2', '1'],
#  ['360.0', '2', '2', '2', '3', '0'],
#  ['361.0', '2', '3', '3', '2', '1'],
#  ['362.0', '2', '3', '2', '2', '1'],
#  ['363.0', '2', '3', '3', '2', '0'],
#  ['364.0', '2', '3', '2', '2', '1'],
#  ['365.0', '2', '3', '3', '2', '1'],
#  ['366.0', '3', '3', '3', '2', '0'],
#  ['367.0', '3', '3', '2', '3', '0'],
#  ['368.0', '3', '2', '2', '2', '1'],
#  ['369.0', '3', '3', '3', '2', '1'],
#  ['370.0', '3', '2', '2', '2', '1'],
#  ['371.0', '3', '2', '3', '2', '0'],
#  ['372.0', '2', '3', '2', '3', '1'],
#  ['373.0', '2', '2', '3', '3', '0'],
#  ['374.0', '2', '2', '2', '2', '1'],
#  ['375.0', '2', '2', '2', '2', '1'],
#  ['376.0', '3', '2', '2', '3', '0'],
#  ['377.0', '3', '2', '2', '2', '1'],
#  ['378.0', '3', '2', '2', '3', '0'],
#  ['379.0', '3', '3', '3', '2', '1'],
#  ['380.0', '3', '3', '2', '3', '0'],
#  ['381.0', '2', '2', '2', '2', '1'],
#  ['382.0', '3', '2', '2', '2', '1'],
#  ['383.0', '3', '2', '2', '2', '0'],
#  ['384.0', '3', '2', '3', '2', '1'],
#  ['385.0', '3', '2', '2', '3', '1'],
#  ['386.0', '3', '3', '3', '2', '1'],
#  ['387.0', '3', '3', '3', '2', '0'],
#  ['388.0', '3', '3', '2', '3', '1'],
#  ['389.0', '3', '3', '3', '2', '1'],
#  ['390.0', '3', '2', '2', '3', '0'],
#  ['391.0', '2', '2', '2', '3', '1'],
#  ['392.0', '2', '2', '2', '2', '1'],
#  ['393.0', '2', '2', '2', '2', '1'],
#  ['394.0', '2', '2', '3', '3', '1'],
#  ['395.0', '2', '2', '2', '2', '1'],
#  ['396.0', '3', '2', '3', '3', '1'],
#  ['397.0', '3', '2', '2', '2', '1'],
#  ['398.0', '3', '3', '2', '3', '0'],
#  ['399.0', '3', '3', '2', '3', '1'],
#  ['400.0', '3', '3', '2', '2', '0'],
#  ['401.0', '3', '3', '2', '3', '1'],
#  ['402.0', '2', '3', '2', '2', '0'],
#  ['403.0', '2', '3', '3', '3', '0'],
#  ['404.0', '2', '3', '3', '3', '0'],
#  ['405.0', '2', '3', '3', '2', '0'],
#  ['406.0', '2', '3', '2', '3', '0'],
#  ['407.0', '3', '3', '3', '3', '0'],
#  ['408.0', '3', '3', '3', '2', '0'],
#  ['409.0', '2', '3', '2', '2', '0'],
#  ['410.0', '2', '3', '3', '2', '0'],
#  ['411.0', '2', '3', '3', '3', '1'],
#  ['412.0', '2', '3', '3', '3', '0'],
#  ['413.0', '2', '3', '3', '2', '0'],
#  ['414.0', '2', '3', '2', '3', '0'],
#  ['415.0', '2', '3', '3', '2', '0'],
#  ['416.0', '2', '3', '2', '3', '0'],
#  ['417.0', '3', '3', '2', '3', '1'],
#  ['418.0', '3', '3', '3', '3', '0'],
#  ['419.0', '3', '3', '3', '3', '0'],
#  ['420.0', '3', '3', '2', '3', '1'],
#  ['421.0', '2', '3', '3', '2', '0'],
#  ['422.0', '2', '3', '3', '3', '0'],
#  ['423.0', '3', '3', '2', '3', '1'],
#  ['424.0', '3', '3', '3', '2', '1'],
#  ['425.0', '3', '3', '3', '3', '1'],
#  ['426.0', '3', '3', '3', '3', '0'],
#  ['427.0', '3', '2', '2', '2', '1'],
#  ['428.0', '3', '3', '3', '3', '0'],
#  ['429.0', '2', '3', '2', '2', '0'],
#  ['430.0', '2', '2', '2', '3', '1'],
#  ['431.0', '2', '3', '2', '2', '0'],
#  ['432.0', '2', '3', '3', '3', '1'],
#  ['433.0', '2', '3', '3', '2', '1'],
#  ['434.0', '2', '3', '3', '2', '0'],
#  ['435.0', '2', '2', '2', '3', '1'],
#  ['436.0', '2', '3', '2', '3', '1'],
#  ['437.0', '2', '3', '2', '2', '1'],
#  ['438.0', '2', '3', '3', '3', '1'],
#  ['439.0', '2', '2', '2', '2', '1'],
#  ['440.0', '3', '2', '3', '2', '0'],
#  ['441.0', '3', '2', '3', '3', '0'],
#  ['442.0', '3', '3', '2', '2', '0'],
#  ['443.0', '3', '3', '2', '3', '0'],
#  ['444.0', '3', '3', '3', '2', '1'],
#  ['445.0', '3', '3', '2', '2', '0'],
#  ['446.0', '3', '3', '2', '3', '1'],
#  ['447.0', '3', '3', '3', '2', '1'],
#  ['448.0', '3', '3', '3', '2', '1'],
#  ['449.0', '3', '3', '3', '2', '0'],
#  ['450.0', '2', '3', '3', '3', '0'],
#  ['451.0', '2', '3', '2', '3', '0'],
#  ['452.0', '2', '3', '3', '3', '1'],
#  ['453.0', '2', '2', '3', '2', '1'],
#  ['454.0', '2', '3', '2', '3', '0'],
#  ['455.0', '2', '3', '3', '2', '1'],
#  ['456.0', '2', '3', '3', '2', '0'],
#  ['457.0', '3', '2', '2', '2', '1'],
#  ['458.0', '3', '2', '3', '3', '1'],
#  ['459.0', '3', '2', '3', '2', '0'],
#  ['460.0', '3', '2', '3', '3', '1'],
#  ['461.0', '2', '2', '2', '3', '0'],
#  ['462.0', '2', '3', '2', '3', '1'],
#  ['463.0', '2', '2', '3', '3', '1'],
#  ['464.0', '2', '2', '2', '3', '0'],
#  ['465.0', '2', '3', '2', '3', '1'],
#  ['466.0', '3', '2', '3', '2', '1'],
#  ['467.0', '2', '2', '3', '3', '1'],
#  ['468.0', '2', '2', '3', '2', '1'],
#  ['469.0', '2', '2', '3', '2', '1'],
#  ['470.0', '2', '2', '3', '2', '0'],
#  ['471.0', '2', '2', '3', '3', '1'],
#  ['472.0', '2', '2', '3', '3', '1'],
#  ['473.0', '3', '3', '3', '2', '1'],
#  ['474.0', '2', '2', '2', '2', '1'],
#  ['475.0', '2', '2', '2', '2', '0'],
#  ['476.0', '2', '3', '3', '2', '1'],
#  ['477.0', '2', '2', '3', '2', '0'],
#  ['478.0', '2', '2', '3', '3', '1'],
#  ['479.0', '2', '2', '2', '3', '1'],
#  ['480.0', '3', '2', '2', '2', '1'],
#  ['481.0', '3', '3', '3', '2', '1'],
#  ['482.0', '3', '3', '3', '3', '1'],
#  ['483.0', '2', '3', '2', '2', '1'],
#  ['484.0', '2', '3', '3', '2', '1'],
#  ['485.0', '3', '3', '3', '3', '1'],
#  ['486.0', '2', '3', '2', '3', '1'],
#  ['487.0', '2', '3', '3', '2', '1'],
#  ['488.0', '2', '3', '3', '2', '1'],
#  ['489.0', '2', '3', '2', '3', '1'],
#  ['490.0', '3', '3', '3', '2', '1'],
#  ['491.0', '3', '2', '3', '3', '0'],
#  ['492.0', '3', '3', '3', '2', '1'],
#  ['493.0', '2', '3', '2', '3', '1'],
#  ['494.0', '2', '3', '2', '3', '1'],
#  ['495.0', '3', '2', '3', '2', '1'],
#  ['496.0', '3', '2', '3', '2', '0'],
#  ['497.0', '3', '2', '3', '2', '1'],
#  ['498.0', '3', '3', '3', '2', '0'],
#  ['499.0', '3', '3', '2', '3', '1'],
#  ['500.0', '3', '3', '2', '3', '1'],
#  ['501.0', '3', '2', '2', '2', '1'],
#  ['502.0', '3', '2', '3', '2', '1'],
#  ['503.0', '2', '3', '2', '2', '1'],
#  ['504.0', '2', '3', '3', '3', '1'],
#  ['505.0', '2', '3', '3', '3', '0'],
#  ['506.0', '2', '3', '2', '2', '1'],
#  ['507.0', '2', '3', '2', '3', '1'],
#  ['508.0', '2', '3', '3', '3', '0'],
#  ['509.0', '2', '2', '3', '3', '1'],
#  ['510.0', '2', '3', '3', '3', '0'],
#  ['511.0', '2', '2', '2', '2', '1'],
#  ['512.0', '2', '3', '3', '3', '1'],
#  ['513.0', '3', '2', '3', '3', '1'],
#  ['514.0', '3', '3', '2', '2', '1'],
#  ['515.0', '3', '2', '3', '3', '1'],
#  ['516.0', '3', '2', '3', '3', '1'],
#  ['517.0', '3', '2', '2', '2', '1'],
#  ['518.0', '3', '2', '3', '2', '1'],
#  ['519.0', '3', '2', '3', '3', '1'],
#  ['520.0', '3', '2', '2', '3', '0'],
#  ['521.0', '3', '2', '3', '3', '0'],
#  ['522.0', '3', '2', '3', '3', '0'],
#  ['523.0', '3', '3', '2', '2', '0'],
#  ['524.0', '3', '2', '3', '2', '0'],
#  ['525.0', '3', '3', '3', '3', '1'],
#  ['526.0', '3', '3', '3', '2', '1'],
#  ['527.0', '3', '3', '3', '2', '1'],
#  ['528.0', '3', '2', '3', '3', '0'],
#  ['529.0', '3', '3', '2', '2', '1'],
#  ['530.0', '3', '3', '2', '2', '0'],
#  ['531.0', '3', '3', '3', '2', '0'],
#  ['532.0', '3', '2', '2', '2', '1'],
#  ['533.0', '3', '3', '2', '2', '0'],
#  ['534.0', '3', '2', '2', '3', '0'],
#  ['535.0', '3', '3', '3', '2', '1'],
#  ['536.0', '3', '2', '3', '2', '0'],
#  ['537.0', '3', '3', '3', '3', '0'],
#  ['538.0', '3', '3', '3', '3', '1'],
#  ['539.0', '3', '3', '3', '3', '0'],
#  ['540.0', '3', '3', '3', '3', '0'],
#  ['541.0', '3', '3', '2', '3', '0'],
#  ['542.0', '3', '2', '2', '2', '0'],
#  ['543.0', '3', '2', '2', '2', '0'],
#  ['544.0', '3', '2', '3', '2', '0'],
#  ['545.0', '3', '2', '3', '2', '1'],
#  ['546.0', '3', '3', '2', '3', '1'],
#  ['547.0', '3', '2', '3', '2', '1'],
#  ['548.0', '3', '2', '3', '3', '0'],
#  ['549.0', '3', '2', '2', '2', '0'],
#  ['550.0', '3', '2', '2', '2', '0'],
#  ['551.0', '3', '3', '2', '2', '1'],
#  ['552.0', '3', '2', '2', '3', '1'],
#  ['553.0', '3', '3', '3', '2', '0'],
#  ['554.0', '3', '3', '3', '3', '0'],
#  ['555.0', '3', '3', '3', '2', '0'],
#  ['556.0', '3', '2', '2', '2', '0'],
#  ['557.0', '3', '3', '2', '3', '0'],
#  ['558.0', '3', '2', '2', '2', '0'],
#  ['559.0', '3', '3', '3', '3', '0'],
#  ['560.0', '3', '2', '3', '3', '1'],
#  ['561.0', '3', '3', '3', '3', '0'],
#  ['562.0', '3', '3', '3', '2', '0'],
#  ['563.0', '3', '2', '2', '2', '0'],
#  ['564.0', '3', '3', '2', '3', '1'],
#  ['565.0', '3', '3', '2', '3', '0'],
#  ['566.0', '3', '3', '3', '3', '0'],
#  ['567.0', '3', '3', '2', '3', '0'],
#  ['568.0', '3', '2', '2', '2', '0'],
#  ['569.0', '3', '2', '2', '2', '0'],
#  ['570.0', '3', '2', '2', '2', '1'],
#  ['571.0', '3', '2', '2', '2', '0'],
#  ['572.0', '3', '2', '2', '2', '0'],
#  ['573.0', '3', '2', '2', '2', '1'],
#  ['574.0', '3', '3', '2', '3', '1'],
#  ['575.0', '3', '3', '2', '2', '0'],
#  ['576.0', '3', '2', '2', '2', '1'],
#  ['577.0', '3', '2', '2', '2', '0'],
#  ['578.0', '3', '2', '2', '2', '0'],
#  ['579.0', '3', '3', '2', '3', '0'],
#  ['580.0', '3', '2', '2', '2', '0'],
#  ['581.0', '3', '3', '3', '3', '0'],
#  ['582.0', '3', '3', '2', '3', '0'],
#  ['583.0', '3', '2', '2', '3', '0'],
#  ['584.0', '3', '2', '2', '2', '0'],
#  ['585.0', '3', '3', '2', '2', '1'],
#  ['586.0', '3', '2', '3', '3', '0'],
#  ['587.0', '3', '3', '3', '3', '0'],
#  ['588.0', '3', '2', '3', '2', '0'],
#  ['589.0', '3', '2', '3', '3', '0'],
#  ['590.0', '3', '3', '3', '2', '0'],
#  ['591.0', '3', '2', '3', '2', '1'],
#  ['592.0', '3', '2', '2', '3', '1'],
#  ['593.0', '3', '3', '3', '2', '1'],
#  ['594.0', '3', '2', '3', '3', '0'],
#  ['595.0', '3', '3', '3', '2', '1'],
#  ['596.0', '3', '3', '3', '2', '1'],
#  ['597.0', '3', '3', '3', '2', '1'],
#  ['598.0', '3', '2', '2', '2', '0'],
#  ['599.0', '3', '2', '3', '3', '0'],
#  ['600.0', '3', '3', '3', '3', '0'],
#  ['601.0', '3', '3', '2', '2', '0'],
#  ['602.0', '3', '3', '2', '3', '1'],
#  ['603.0', '3', '3', '2', '3', '1'],
#  ['604.0', '3', '2', '3', '3', '1'],
#  ['605.0', '3', '2', '3', '2', '1'],
#  ['606.0', '3', '3', '3', '2', '0'],
#  ['607.0', '3', '2', '3', '2', '1'],
#  ['608.0', '3', '2', '2', '2', '1'],
#  ['609.0', '3', '3', '2', '3', '1'],
#  ['610.0', '3', '2', '3', '3', '0'],
#  ['611.0', '3', '3', '3', '2', '0'],
#  ['612.0', '3', '3', '3', '3', '1'],
#  ['613.0', '3', '3', '2', '2', '0'],
#  ['614.0', '3', '3', '2', '3', '1'],
#  ['615.0', '3', '3', '3', '2', '0'],
#  ['616.0', '3', '3', '2', '3', '0'],
#  ['617.0', '3', '2', '3', '3', '1'],
#  ['618.0', '3', '2', '3', '2', '1'],
#  ['619.0', '3', '3', '3', '3', '0'],
#  ['620.0', '3', '2', '2', '3', '0'],
#  ['621.0', '3', '2', '2', '3', '0'],
#  ['622.0', '3', '2', '2', '3', '0'],
#  ['623.0', '3', '2', '3', '3', '1'],
#  ['624.0', '3', '2', '3', '3', '1'],
#  ['625.0', '3', '3', '3', '2', '1'],
#  ['626.0', '3', '3', '3', '2', '1'],
#  ['627.0', '3', '3', '3', '2', '0'],
#  ['628.0', '3', '3', '2', '3', '0'],
#  ['629.0', '3', '2', '3', '3', '0'],
#  ['630.0', '3', '3', '3', '3', '0'],
#  ['631.0', '3', '2', '3', '2', '0'],
#  ['632.0', '3', '3', '3', '2', '0'],
#  ['633.0', '3', '3', '3', '2', '0'],
#  ['634.0', '3', '3', '3', '2', '0'],
#  ['635.0', '3', '3', '3', '3', '1'],
#  ['636.0', '3', '2', '3', '3', '0'],
#  ['637.0', '3', '3', '3', '2', '0'],
#  ['638.0', '3', '2', '3', '2', '1'],
#  ['639.0', '3', '2', '3', '3', '1'],
#  ['640.0', '3', '3', '3', '3', '0'],
#  ['641.0', '3', '2', '3', '3', '0'],
#  ['642.0', '3', '3', '2', '3', '0'],
#  ['643.0', '3', '3', '2', '2', '1'],
#  ['644.0', '3', '3', '3', '2', '1'],
#  ['645.0', '3', '3', '2', '2', '0'],
#  ['646.0', '3', '2', '2', '3', '0'],
#  ['647.0', '3', '3', '3', '2', '0'],
#  ['648.0', '3', '3', '2', '3', '0'],
#  ['649.0', '3', '2', '3', '3', '0'],
#  ['650.0', '3', '2', '2', '2', '1'],
#  ['651.0', '3', '3', '2', '2', '1'],
#  ['652.0', '3', '2', '2', '3', '0'],
#  ['653.0', '3', '3', '2', '3', '1'],
#  ['654.0', '3', '2', '2', '3', '1'],
#  ['655.0', '3', '2', '2', '3', '1'],
#  ['656.0', '3', '3', '2', '3', '0'],
#  ['657.0', '3', '3', '2', '2', '0'],
#  ['658.0', '3', '3', '2', '2', '0'],
#  ['659.0', '3', '3', '2', '3', '0'],
#  ['660.0', '3', '3', '2', '2', '0'],
#  ['661.0', '3', '3', '3', '3', '1'],
#  ['662.0', '3', '2', '3', '3', '0'],
#  ['663.0', '3', '3', '3', '2', '0'],
#  ['664.0', '3', '2', '3', '2', '0'],
#  ['665.0', '3', '2', '3', '3', '1'],
#  ['666.0', '3', '3', '3', '3', '0'],
#  ['667.0', '3', '3', '3', '2', '0'],
#  ['668.0', '3', '3', '3', '2', '0'],
#  ['669.0', '3', '3', '3', '2', '0'],
#  ['670.0', '3', '3', '3', '3', '0'],
#  ['671.0', '3', '2', '3', '2', '1'],
#  ['672.0', '3', '2', '2', '3', '0'],
#  ['673.0', '3', '2', '3', '3', '1'],
#  ['674.0', '3', '2', '2', '2', '0'],
#  ['675.0', '3', '2', '3', '3', '0'],
#  ['676.0', '3', '2', '2', '2', '1'],
#  ['677.0', '3', '2', '2', '3', '1'],
#  ['678.0', '3', '2', '3', '2', '0'],
#  ['679.0', '3', '2', '3', '2', '1'],
#  ['680.0', '3', '3', '2', '2', '1'],
#  ['681.0', '3', '3', '2', '2', '1'],
#  ['682.0', '3', '3', '3', '2', '1'],
#  ['683.0', '3', '2', '2', '2', '1'],
#  ['684.0', '3', '3', '2', '3', '0'],
#  ['685.0', '3', '3', '2', '3', '0'],
#  ['686.0', '3', '3', '2', '3', '0'],
#  ['687.0', '3', '3', '2', '2', '1'],
#  ['688.0', '3', '2', '2', '3', '0'],
#  ['689.0', '3', '2', '2', '3', '0'],
#  ['690.0', '3', '3', '2', '2', '0'],
#  ['691.0', '3', '3', '2', '2', '1'],
#  ['692.0', '3', '2', '2', '2', '0'],
#  ['693.0', '3', '3', '3', '3', '0'],
#  ['694.0', '3', '3', '2', '3', '0'],
#  ['695.0', '3', '2', '2', '2', '0'],
#  ['696.0', '3', '2', '2', '3', '0'],
#  ['697.0', '3', '3', '2', '3', '1'],
#  ['698.0', '3', '2', '2', '2', '0'],
#  ['699.0', '3', '2', '2', '3', '0'],
#  ['700.0', '3', '2', '2', '2', '0'],
#  ['701.0', '3', '2', '3', '2', '0'],
#  ['702.0', '3', '2', '2', '2', '0'],
#  ['703.0', '3', '2', '3', '3', '0'],
#  ['704.0', '3', '2', '2', '2', '0'],
#  ['705.0', '3', '3', '2', '3', '1'],
#  ['706.0', '3', '2', '2', '2', '1'],
#  ['707.0', '3', '2', '2', '2', '0'],
#  ['708.0', '3', '3', '3', '2', '0'],
#  ['709.0', '3', '3', '2', '2', '0'],
#  ['710.0', '3', '3', '3', '2', '0'],
#  ['711.0', '3', '3', '3', '2', '1'],
#  ['712.0', '3', '3', '3', '2', '0'],
#  ['713.0', '3', '2', '3', '3', '1'],
#  ['714.0', '3', '3', '2', '2', '0'],
#  ['715.0', '3', '3', '3', '3', '0'],
#  ['716.0', '3', '2', '2', '3', '0'],
#  ['717.0', '3', '3', '3', '2', '1'],
#  ['718.0', '3', '3', '2', '3', '0'],
#  ['719.0', '3', '2', '3', '3', '0'],
#  ['720.0', '3', '3', '3', '3', '0'],
#  ['721.0', '3', '3', '2', '2', '0'],
#  ['722.0', '3', '2', '2', '3', '0'],
#  ['723.0', '3', '3', '3', '2', '0'],
#  ['724.0', '3', '2', '2', '2', '1'],
#  ['725.0', '3', '3', '3', '2', '0'],
#  ['726.0', '3', '3', '2', '3', '1'],
#  ['727.0', '3', '3', '2', '3', '0'],
#  ['728.0', '3', '2', '3', '3', '1'],
#  ['729.0', '3', '2', '2', '2', '0'],
#  ['730.0', '3', '2', '3', '2', '1'],
#  ['731.0', '3', '2', '3', '3', '1'],
#  ['732.0', '3', '2', '2', '2', '0'],
#  ['733.0', '3', '2', '2', '2', '0'],
#  ['734.0', '3', '3', '2', '3', '1'],
#  ['735.0', '3', '2', '2', '2', '0'],
#  ['736.0', '3', '3', '2', '3', '0'],
#  ['737.0', '3', '3', '2', '3', '0'],
#  ['738.0', '3', '2', '2', '2', '0'],
#  ['739.0', '3', '3', '3', '3', '0'],
#  ['740.0', '3', '3', '3', '2', '1'],
#  ['741.0', '3', '3', '2', '3', '1'],
#  ['742.0', '3', '3', '2', '3', '1'],
#  ['743.0', '3', '2', '2', '2', '0'],
#  ['744.0', '3', '3', '3', '2', '1'],
#  ['745.0', '3', '3', '2', '3', '1'],
#  ['746.0', '3', '3', '2', '3', '1'],
#  ['747.0', '3', '3', '2', '3', '1'],
#  ['748.0', '3', '2', '3', '2', '0'],
#  ['749.0', '3', '2', '2', '2', '0'],
#  ['750.0', '3', '3', '2', '3', '1'],
#  ['751.0', '3', '2', '2', '3', '0'],
#  ['752.0', '3', '3', '2', '3', '1'],
#  ['753.0', '3', '2', '2', '2', '1'],
#  ['754.0', '3', '3', '2', '3', '0'],
#  ['755.0', '3', '2', '2', '2', '0'],
#  ['756.0', '3', '3', '2', '3', '1'],
#  ['757.0', '3', '3', '2', '3', '0'],
#  ['758.0', '3', '2', '2', '2', '1'],
#  ['759.0', '3', '2', '2', '2', '1'],
#  ['760.0', '3', '3', '2', '3', '1'],
#  ['761.0', '3', '3', '3', '2', '0'],
#  ['762.0', '3', '2', '3', '3', '1'],
#  ['763.0', '3', '2', '3', '3', '0'],
#  ['764.0', '3', '3', '3', '2', '0'],
#  ['765.0', '3', '2', '3', '3', '0'],
#  ['766.0', '3', '3', '3', '3', '0'],
#  ['767.0', '3', '3', '3', '3', '0'],
#  ['768.0', '3', '3', '3', '2', '0'],
#  ['769.0', '3', '3', '3', '3', '0'],
#  ['770.0', '3', '3', '3', '2', '1'],
#  ['771.0', '3', '3', '3', '2', '0'],
#  ['772.0', '3', '2', '3', '3', '0'],
#  ['773.0', '3', '3', '3', '2', '1'],
#  ['774.0', '3', '3', '3', '3', '0'],
#  ['775.0', '3', '3', '3', '3', '1'],
#  ['776.0', '3', '3', '3', '2', '1'],
#  ['777.0', '3', '3', '3', '2', '0'],
#  ['778.0', '3', '3', '3', '3', '0'],
#  ['779.0', '3', '2', '3', '3', '0'],
#  ['780.0', '3', '3', '3', '2', '0'],
#  ['781.0', '3', '3', '3', '3', '1'],
#  ['782.0', '3', '3', '3', '3', '0'],
#  ['783.0', '3', '3', '3', '2', '1'],
#  ['784.0', '3', '2', '3', '2', '1'],
#  ['785.0', '3', '3', '3', '2', '1'],
#  ['786.0', '3', '3', '3', '2', '1'],
#  ['787.0', '3', '3', '3', '2', '0'],
#  ['788.0', '3', '2', '3', '3', '0'],
#  ['789.0', '3', '2', '3', '3', '0'],
#  ['790.0', '3', '2', '3', '3', '1'],
#  ['791.0', '3', '2', '3', '3', '1'],
#  ['792.0', '3', '2', '3', '3', '0'],
#  ['793.0', '3', '3', '3', '2', '1'],
#  ['794.0', '3', '3', '3', '2', '1'],
#  ['795.0', '3', '3', '3', '2', '0'],
#  ['796.0', '3', '3', '3', '2', '1'],
#  ['797.0', '3', '3', '3', '2', '1'],
#  ['798.0', '3', '2', '3', '3', '1'],
#  ['799.0', '3', '2', '3', '3', '1'],
#  ['800.0', '3', '3', '3', '2', '1'],
#  ['801.0', '3', '3', '3', '3', '0'],
#  ['802.0', '3', '2', '3', '3', '0'],
#  ['803.0', '3', '3', '3', '2', '1'],
#  ['804.0', '3', '2', '3', '3', '1'],
#  ['805.0', '3', '3', '3', '2', '1'],
#  ['806.0', '3', '3', '3', '2', '1'],
#  ['807.0', '3', '3', '3', '2', '1'],
#  ['808.0', '3', '2', '3', '3', '1'],
#  ['809.0', '3', '2', '3', '3', '1'],
#  ['810.0', '3', '2', '3', '3', '1']]

# %%
def find_best_split(rows):
    """Find the best question to ask by iterating over every feature / value
    and calculating the information gain."""
    best_gain = 0  # keep track of the best information gain
    best_question = None  # keep train of the feature / value that produced it
    current_uncertainty = gini(rows)
    n_features = len(rows[0]) - 1  # number of columns

    for col in range(n_features):  # for each feature

        values = set([row[col] for row in rows])  # unique values in the column

        for val in values:  # for each value

            question = Question(col, val)

            # try splitting the dataset
            true_rows, false_rows = partition(rows, question)

            # Skip this split if it doesn't divide the
            # dataset.
            if len(true_rows) == 0 or len(false_rows) == 0:
                continue

            # Calculate the information gain from this split
            gain = info_gain(true_rows, false_rows, current_uncertainty)

            # You actually can use '>' instead of '>=' here
            # but I wanted the tree to look a certain way for our
            # toy dataset.
            if gain >= best_gain:
                best_gain, best_question = gain, question

    return best_gain, best_question

# %%
best_gain, best_question = find_best_split(training_set)
best_question
# Out:
# Is day/night == 2?

# %%
class Leaf:
    """A Leaf node classifies data.

    This holds a dictionary of class (e.g., "Apple") -> number of times
    it appears in the rows from the training data that reach this leaf.
    """

    def __init__(self, rows):
        self.predictions = class_counts(rows)

# %%
class Decision_Node:
    """A Decision Node asks a question.

    This holds a reference to the question, and to the two child nodes.
    """

    def __init__(self,
                 question,
                 true_branch,
                 false_branch):
        self.question = question
        self.true_branch = true_branch
        self.false_branch = false_branch

# %%
def build_tree(rows):
    """Builds the tree.

    Rules of recursion: 1) Believe that it works. 2) Start by checking
    for the base case (no further information gain). 3) Prepare for
    giant stack traces.
    """

    # Try partitioing the dataset on each of the unique attribute,
    # calculate the information gain,
    # and return the question that produces the highest gain.
    gain, question = find_best_split(rows)

    # Base case: no further info gain
    # Since we can ask no further questions,
    # we'll return a leaf.
    if gain == 0:
        return Leaf(rows)

    # If we reach here, we have found a useful feature / value
    # to partition on.
    true_rows, false_rows = partition(rows, question)

    # Recursively build the true branch.
    true_branch = build_tree(true_rows)

    # Recursively build the false branch.
    false_branch = build_tree(false_rows)

    # Return a Question node.
    # This records the best feature / value to ask at this point,
    # as well as the branches to follow
    # dependingo on the answer.
    return Decision_Node(question, true_branch, false_branch)

# %%
def print_tree(node, spacing=""):
    """World's most elegant tree printing function."""

    # Base case: we've reached a leaf
    if isinstance(node, Leaf):
        print (spacing + "Predict", node.predictions)
        return

    # Print the question at this node
    print (spacing + str(node.question))

    # Call this function recursively on the true branch
    print (spacing + '--> True:')
    print_tree(node.true_branch, spacing + "  ")

    # Call this function recursively on the false branch
    print (spacing + '--> False:')
    print_tree(node.false_branch, spacing + "  ")

# %%
my_tree = build_tree(training_set)

# %%
print_tree(my_tree)
# Out:
# Is day/night == 2?
# --> True:
#   Is toss == 3?
#   --> True:
#     Is win == 3?
#     --> True:
#       Is home/away == 450.0?
#       --> True:
#         Predict {'0': 1}
#       --> False:
#         Is home/away == 275.0?
#         --> True:
#           Predict {'0': 1}
#         --> False:
#           Is home/away == 49.0?
#           --> True:
#             Predict {'0': 1}
#           --> False:
#             Is home/away == 7.0?
#             --> True:
#               Predict {'0': 1}
#             --> False:
#               Is home/away == 62.0?
#               --> True:
#                 Predict {'0': 1}
#               --> False:
#                 Is home/away == 338.0?
#                 --> True:
#                   Predict {'0': 1}
#                 --> False:
#                   Is home/away == 18.0?
#                   --> True:
#                     Predict {'0': 1}
#                   --> False:
#                     Is home/away == 4.0?
#                     --> True:
#                       Predict {'0': 1}
#                     --> False:
#                       Is home/away == 21.0?
#                       --> True:
#                         Predict {'0': 1}
#                       --> False:
#                         Is home/away == 16.0?
#                         --> True:
#                           Predict {'0': 1}
#                         --> False:
#                           Is home/away == 2.0?
#                           --> True:
#                             Predict {'0': 1}
#                           --> False:
#                             Is home/away == 177.0?
#                             --> True:
#                               Predict {'0': 1}
#                             --> False:
#                               Is home/away == 505.0?
#                               --> True:
#                                 Predict {'0': 1}
#                               --> False:
#                                 Is home/away == 1.0?
#                                 --> True:
#                                   Predict {'0': 1}
#                                 --> False:
#                                   Is home/away == 133.0?
#                                   --> True:
#                                     Predict {'0': 1}
#                                   --> False:
#                                     Is home/away == 175.0?
#                                     --> True:
#                                       Predict {'0': 1}
#                                     --> False:
#                                       Is home/away == 52.0?
#                                       --> True:
#                                         Predict {'0': 1}
#                                       --> False:
#                                         Is home/away == 54.0?
#                                         --> True:
#                                           Predict {'0': 1}
#                                         --> False:
#                                           Is home/away == 179.0?
#                                           --> True:
#                                             Predict {'0': 1}
#                                           --> False:
#                                             Is home/away == 404.0?
#                                             --> True:
#                                               Predict {'0': 1}
#                                             --> False:
#                                               Is home/away == 414.0?
#                                               --> True:
#                                                 Predict {'0': 1}
#                                               --> False:
#                                                 Is home/away == 75.0?
#                                                 --> True:
#                                                   Predict {'0': 1}
#                                                 --> False:
#                                                   Is home/away == 283.0?
#                                                   --> True:
#                                                     Predict {'0': 1}
#                                                   --> False:
#                                                     Is home/away == 406.0?
#                                                     --> True:
#                                                       Predict {'0': 1}
#                                                     --> False:
#                                                       Is home/away == 92.0?
#                                                       --> True:
#                                                         Predict {'0': 1}
#                                                       --> False:
#                                                         Is home/away == 174.0?
#                                                         --> True:
#                                                           Predict {'0': 1}
#                                                         --> False:
#                                                           Is batted first == 3?
#                                                           --> True:
#                                                             Is home/away == 241.0?
#                                                             --> True:
#                                                               Predict {'0': 1}
#                                                             --> False:
#                                                               Is home/away == 38.0?
#                                                               --> True:
#                                                                 Predict {'0': 1}
#                                                               --> False:
#                                                                 Is home/away == 422.0?
#                                                                 --> True:
#                                                                   Predict {'0': 1}
#                                                                 --> False:
#                                                                   Is home/away == 342.0?
#                                                                   --> True:
#                                                                     Predict {'0': 1}
#                                                                   --> False:
#                                                                     Is home/away == 329.0?
#                                                                     --> True:
#                                                                       Predict {'0': 1}
#                                                                     --> False:
#                                                                       Is home/away == 510.0?
#                                                                       --> True:
#                                                                         Predict {'0': 1}
#                                                                       --> False:
#                                                                         Is home/away == 403.0?
#                                                                         --> True:
#                                                                           Predict {'0': 1}
#                                                                         --> False:
#                                                                           Is home/away == 508.0?
#                                                                           --> True:
#                                                                             Predict {'0': 1}
#                                                                           --> False:
#                                                                             Is home/away == 412.0?
#                                                                             --> True:
#                                                                               Predict {'0': 1}
#                                                                             --> False:
#                                                                               Is home/away == 30.0?
#                                                                               --> True:
#                                                                                 Predict {'0': 1}
#                                                                               --> False:
#                                                                                 Is home/away == 242.0?
#                                                                                 --> True:
#                                                                                   Predict {'0': 1}
#                                                                                 --> False:
#                                                                                   Predict {'1': 18}
#                                                           --> False:
#                                                             Is home/away == 454.0?
#                                                             --> True:
#                                                               Predict {'0': 1}
#                                                             --> False:
#                                                               Is home/away == 416.0?
#                                                               --> True:
#                                                                 Predict {'0': 1}
#                                                               --> False:
#                                                                 Is home/away == 292.0?
#                                                                 --> True:
#                                                                   Predict {'0': 1}
#                                                                 --> False:
#                                                                   Is home/away == 59.0?
#                                                                   --> True:
#                                                                     Predict {'0': 1}
#                                                                   --> False:
#                                                                     Is home/away == 451.0?
#                                                                     --> True:
#                                                                       Predict {'0': 1}
#                                                                     --> False:
#                                                                       Is home/away == 335.0?
#                                                                       --> True:
#                                                                         Predict {'0': 1}
#                                                                       --> False:
#                                                                         Predict {'1': 27}
#     --> False:
#       Is home/away == 145.0?
#       --> True:
#         Predict {'0': 1}
#       --> False:
#         Is home/away == 28.0?
#         --> True:
#           Predict {'0': 1}
#         --> False:
#           Is home/away == 136.0?
#           --> True:
#             Predict {'0': 1}
#           --> False:
#             Is home/away == 185.0?
#             --> True:
#               Predict {'0': 1}
#             --> False:
#               Is home/away == 456.0?
#               --> True:
#                 Predict {'0': 1}
#               --> False:
#                 Is home/away == 56.0?
#                 --> True:
#                   Predict {'0': 1}
#                 --> False:
#                   Is home/away == 413.0?
#                   --> True:
#                     Predict {'0': 1}
#                   --> False:
#                     Is home/away == 243.0?
#                     --> True:
#                       Predict {'0': 1}
#                     --> False:
#                       Is home/away == 421.0?
#                       --> True:
#                         Predict {'0': 1}
#                       --> False:
#                         Is home/away == 178.0?
#                         --> True:
#                           Predict {'0': 1}
#                         --> False:
#                           Is home/away == 27.0?
#                           --> True:
#                             Predict {'0': 1}
#                           --> False:
#                             Is home/away == 429.0?
#                             --> True:
#                               Predict {'0': 1}
#                             --> False:
#                               Is home/away == 405.0?
#                               --> True:
#                                 Predict {'0': 1}
#                               --> False:
#                                 Is home/away == 363.0?
#                                 --> True:
#                                   Predict {'0': 1}
#                                 --> False:
#                                   Is home/away == 240.0?
#                                   --> True:
#                                     Predict {'0': 1}
#                                   --> False:
#                                     Is home/away == 257.0?
#                                     --> True:
#                                       Predict {'0': 1}
#                                     --> False:
#                                       Is home/away == 402.0?
#                                       --> True:
#                                         Predict {'0': 1}
#                                       --> False:
#                                         Is home/away == 33.0?
#                                         --> True:
#                                           Predict {'0': 1}
#                                         --> False:
#                                           Is home/away == 61.0?
#                                           --> True:
#                                             Predict {'0': 1}
#                                           --> False:
#                                             Is home/away == 415.0?
#                                             --> True:
#                                               Predict {'0': 1}
#                                             --> False:
#                                               Is home/away == 53.0?
#                                               --> True:
#                                                 Predict {'0': 1}
#                                               --> False:
#                                                 Is home/away == 142.0?
#                                                 --> True:
#                                                   Predict {'0': 1}
#                                                 --> False:
#                                                   Is home/away == 274.0?
#                                                   --> True:
#                                                     Predict {'0': 1}
#                                                   --> False:
#                                                     Is home/away == 66.0?
#                                                     --> True:
#                                                       Predict {'0': 1}
#                                                     --> False:
#                                                       Is home/away == 20.0?
#                                                       --> True:
#                                                         Predict {'0': 1}
#                                                       --> False:
#                                                         Is home/away == 305.0?
#                                                         --> True:
#                                                           Predict {'0': 1}
#                                                         --> False:
#                                                           Is home/away == 409.0?
#                                                           --> True:
#                                                             Predict {'0': 1}
#                                                           --> False:
#                                                             Is home/away == 8.0?
#                                                             --> True:
#                                                               Predict {'0': 1}
#                                                             --> False:
#                                                               Is home/away == 57.0?
#                                                               --> True:
#                                                                 Predict {'0': 1}
#                                                               --> False:
#                                                                 Is home/away == 69.0?
#                                                                 --> True:
#                                                                   Predict {'0': 1}
#                                                                 --> False:
#                                                                   Is home/away == 431.0?
#                                                                   --> True:
#                                                                     Predict {'0': 1}
#                                                                   --> False:
#                                                                     Is home/away == 410.0?
#                                                                     --> True:
#                                                                       Predict {'0': 1}
#                                                                     --> False:
#                                                                       Is home/away == 434.0?
#                                                                       --> True:
#                                                                         Predict {'0': 1}
#                                                                       --> False:
#                                                                         Is home/away == 330.0?
#                                                                         --> True:
#                                                                           Predict {'0': 1}
#                                                                         --> False:
#                                                                           Is home/away == 317.0?
#                                                                           --> True:
#                                                                             Predict {'0': 1}
#                                                                           --> False:
#                                                                             Is home/away == 285.0?
#                                                                             --> True:
#                                                                               Predict {'0': 1}
#                                                                             --> False:
#                                                                               Is home/away == 219.0?
#                                                                               --> True:
#                                                                                 Predict {'0': 1}
#                                                                               --> False:
#                                                                                 Is home/away == 31.0?
#                                                                                 --> True:
#                                                                                   Predict {'0': 1}
#                                                                                 --> False:
#                                                                                   Predict {'1': 60}
#   --> False:
#     Is batted first == 2?
#     --> True:
#       Is home/away == 23.0?
#       --> True:
#         Predict {'0': 1}
#       --> False:
#         Is home/away == 25.0?
#         --> True:
#           Predict {'0': 1}
#         --> False:
#           Is home/away == 360.0?
#           --> True:
#             Predict {'0': 1}
#           --> False:
#             Is home/away == 307.0?
#             --> True:
#               Predict {'0': 1}
#             --> False:
#               Is home/away == 221.0?
#               --> True:
#                 Predict {'0': 1}
#               --> False:
#                 Is home/away == 11.0?
#                 --> True:
#                   Predict {'0': 1}
#                 --> False:
#                   Is home/away == 88.0?
#                   --> True:
#                     Predict {'0': 1}
#                   --> False:
#                     Is home/away == 0.0?
#                     --> True:
#                       Predict {'0': 1}
#                     --> False:
#                       Is home/away == 309.0?
#                       --> True:
#                         Predict {'0': 1}
#                       --> False:
#                         Is home/away == 461.0?
#                         --> True:
#                           Predict {'0': 1}
#                         --> False:
#                           Is home/away == 37.0?
#                           --> True:
#                             Predict {'0': 1}
#                           --> False:
#                             Is home/away == 301.0?
#                             --> True:
#                               Predict {'0': 1}
#                             --> False:
#                               Is home/away == 294.0?
#                               --> True:
#                                 Predict {'0': 1}
#                               --> False:
#                                 Is home/away == 464.0?
#                                 --> True:
#                                   Predict {'0': 1}
#                                 --> False:
#                                   Is home/away == 203.0?
#                                   --> True:
#                                     Predict {'0': 1}
#                                   --> False:
#                                     Is home/away == 24.0?
#                                     --> True:
#                                       Predict {'0': 1}
#                                     --> False:
#                                       Is home/away == 70.0?
#                                       --> True:
#                                         Predict {'0': 1}
#                                       --> False:
#                                         Is home/away == 475.0?
#                                         --> True:
#                                           Predict {'0': 1}
#                                         --> False:
#                                           Is home/away == 43.0?
#                                           --> True:
#                                             Predict {'0': 1}
#                                           --> False:
#                                             Is home/away == 273.0?
#                                             --> True:
#                                               Predict {'0': 1}
#                                             --> False:
#                                               Is home/away == 41.0?
#                                               --> True:
#                                                 Predict {'0': 1}
#                                               --> False:
#                                                 Predict {'1': 33}
#     --> False:
#       Is home/away == 220.0?
#       --> True:
#         Predict {'0': 1}
#       --> False:
#         Is home/away == 265.0?
#         --> True:
#           Predict {'0': 1}
#         --> False:
#           Is home/away == 36.0?
#           --> True:
#             Predict {'0': 1}
#           --> False:
#             Is home/away == 152.0?
#             --> True:
#               Predict {'0': 1}
#             --> False:
#               Is home/away == 258.0?
#               --> True:
#                 Predict {'0': 1}
#               --> False:
#                 Is home/away == 250.0?
#                 --> True:
#                   Predict {'0': 1}
#                 --> False:
#                   Is home/away == 247.0?
#                   --> True:
#                     Predict {'0': 1}
#                   --> False:
#                     Is home/away == 340.0?
#                     --> True:
#                       Predict {'0': 1}
#                     --> False:
#                       Is home/away == 302.0?
#                       --> True:
#                         Predict {'0': 1}
#                       --> False:
#                         Is home/away == 477.0?
#                         --> True:
#                           Predict {'0': 1}
#                         --> False:
#                           Is home/away == 237.0?
#                           --> True:
#                             Predict {'0': 1}
#                           --> False:
#                             Is home/away == 470.0?
#                             --> True:
#                               Predict {'0': 1}
#                             --> False:
#                               Is home/away == 26.0?
#                               --> True:
#                                 Predict {'0': 1}
#                               --> False:
#                                 Is home/away == 373.0?
#                                 --> True:
#                                   Predict {'0': 1}
#                                 --> False:
#                                   Predict {'1': 41}
# --> False:
#   Is day/night == 3?
#   --> True:
#     Is batted first == 2?
#     --> True:
#       Is toss == 2?
#       --> True:
#         Is win == 2?
#         --> True:
#           Is home/away == 94.0?
#           --> True:
#             Predict {'1': 1}
#           --> False:
#             Is home/away == 573.0?
#             --> True:
#               Predict {'1': 1}
#             --> False:
#               Is home/away == 532.0?
#               --> True:
#                 Predict {'1': 1}
#               --> False:
#                 Is home/away == 608.0?
#                 --> True:
#                   Predict {'1': 1}
#                 --> False:
#                   Is home/away == 457.0?
#                   --> True:
#                     Predict {'1': 1}
#                   --> False:
#                     Is home/away == 676.0?
#                     --> True:
#                       Predict {'1': 1}
#                     --> False:
#                       Is home/away == 377.0?
#                       --> True:
#                         Predict {'1': 1}
#                       --> False:
#                         Is home/away == 169.0?
#                         --> True:
#                           Predict {'1': 1}
#                         --> False:
#                           Is home/away == 501.0?
#                           --> True:
#                             Predict {'1': 1}
#                           --> False:
#                             Is home/away == 368.0?
#                             --> True:
#                               Predict {'1': 1}
#                             --> False:
#                               Is home/away == 759.0?
#                               --> True:
#                                 Predict {'1': 1}
#                               --> False:
#                                 Is home/away == 223.0?
#                                 --> True:
#                                   Predict {'1': 1}
#                                 --> False:
#                                   Is home/away == 480.0?
#                                   --> True:
#                                     Predict {'1': 1}
#                                   --> False:
#                                     Is home/away == 576.0?
#                                     --> True:
#                                       Predict {'1': 1}
#                                     --> False:
#                                       Is home/away == 570.0?
#                                       --> True:
#                                         Predict {'1': 1}
#                                       --> False:
#                                         Is home/away == 157.0?
#                                         --> True:
#                                           Predict {'1': 1}
#                                         --> False:
#                                           Is home/away == 370.0?
#                                           --> True:
#                                             Predict {'1': 1}
#                                           --> False:
#                                             Is home/away == 753.0?
#                                             --> True:
#                                               Predict {'1': 1}
#                                             --> False:
#                                               Is home/away == 382.0?
#                                               --> True:
#                                                 Predict {'1': 1}
#                                               --> False:
#                                                 Is home/away == 683.0?
#                                                 --> True:
#                                                   Predict {'1': 1}
#                                                 --> False:
#                                                   Is home/away == 254.0?
#                                                   --> True:
#                                                     Predict {'1': 1}
#                                                   --> False:
#                                                     Is home/away == 724.0?
#                                                     --> True:
#                                                       Predict {'1': 1}
#                                                     --> False:
#                                                       Is home/away == 706.0?
#                                                       --> True:
#                                                         Predict {'1': 1}
#                                                       --> False:
#                                                         Is home/away == 256.0?
#                                                         --> True:
#                                                           Predict {'1': 1}
#                                                         --> False:
#                                                           Is home/away == 758.0?
#                                                           --> True:
#                                                             Predict {'1': 1}
#                                                           --> False:
#                                                             Is home/away == 517.0?
#                                                             --> True:
#                                                               Predict {'1': 1}
#                                                             --> False:
#                                                               Is home/away == 397.0?
#                                                               --> True:
#                                                                 Predict {'1': 1}
#                                                               --> False:
#                                                                 Is home/away == 427.0?
#                                                                 --> True:
#                                                                   Predict {'1': 1}
#                                                                 --> False:
#                                                                   Is home/away == 650.0?
#                                                                   --> True:
#                                                                     Predict {'1': 1}
#                                                                   --> False:
#                                                                     Is home/away == 230.0?
#                                                                     --> True:
#                                                                       Predict {'1': 1}
#                                                                     --> False:
#                                                                       Is home/away == 168.0?
#                                                                       --> True:
#                                                                         Predict {'1': 1}
#                                                                       --> False:
#                                                                         Predict {'0': 44}
#         --> False:
#           Is home/away == 344.0?
#           --> True:
#             Predict {'1': 1}
#           --> False:
#             Is home/away == 654.0?
#             --> True:
#               Predict {'1': 1}
#             --> False:
#               Is home/away == 677.0?
#               --> True:
#                 Predict {'1': 1}
#               --> False:
#                 Is home/away == 385.0?
#                 --> True:
#                   Predict {'1': 1}
#                 --> False:
#                   Is home/away == 655.0?
#                   --> True:
#                     Predict {'1': 1}
#                   --> False:
#                     Is home/away == 592.0?
#                     --> True:
#                       Predict {'1': 1}
#                     --> False:
#                       Is home/away == 552.0?
#                       --> True:
#                         Predict {'1': 1}
#                       --> False:
#                         Predict {'0': 21}
#       --> False:
#         Is home/away == 106.0?
#         --> True:
#           Predict {'1': 1}
#         --> False:
#           Is home/away == 150.0?
#           --> True:
#             Predict {'1': 1}
#           --> False:
#             Is home/away == 514.0?
#             --> True:
#               Predict {'1': 1}
#             --> False:
#               Is home/away == 399.0?
#               --> True:
#                 Predict {'1': 1}
#               --> False:
#                 Is home/away == 279.0?
#                 --> True:
#                   Predict {'1': 1}
#                 --> False:
#                   Is home/away == 585.0?
#                   --> True:
#                     Predict {'1': 1}
#                   --> False:
#                     Is win == 2?
#                     --> True:
#                       Is home/away == 551.0?
#                       --> True:
#                         Predict {'1': 1}
#                       --> False:
#                         Is home/away == 233.0?
#                         --> True:
#                           Predict {'1': 1}
#                         --> False:
#                           Is home/away == 352.0?
#                           --> True:
#                             Predict {'1': 1}
#                           --> False:
#                             Is home/away == 336.0?
#                             --> True:
#                               Predict {'1': 1}
#                             --> False:
#                               Is home/away == 155.0?
#                               --> True:
#                                 Predict {'1': 1}
#                               --> False:
#                                 Is home/away == 691.0?
#                                 --> True:
#                                   Predict {'1': 1}
#                                 --> False:
#                                   Is home/away == 529.0?
#                                   --> True:
#                                     Predict {'1': 1}
#                                   --> False:
#                                     Is home/away == 211.0?
#                                     --> True:
#                                       Predict {'1': 1}
#                                     --> False:
#                                       Is home/away == 651.0?
#                                       --> True:
#                                         Predict {'1': 1}
#                                       --> False:
#                                         Is home/away == 205.0?
#                                         --> True:
#                                           Predict {'1': 1}
#                                         --> False:
#                                           Is home/away == 681.0?
#                                           --> True:
#                                             Predict {'1': 1}
#                                           --> False:
#                                             Is home/away == 643.0?
#                                             --> True:
#                                               Predict {'1': 1}
#                                             --> False:
#                                               Is home/away == 680.0?
#                                               --> True:
#                                                 Predict {'1': 1}
#                                               --> False:
#                                                 Is home/away == 687.0?
#                                                 --> True:
#                                                   Predict {'1': 1}
#                                                 --> False:
#                                                   Predict {'0': 24}
#                     --> False:
#                       Is home/away == 697.0?
#                       --> True:
#                         Predict {'1': 1}
#                       --> False:
#                         Is home/away == 726.0?
#                         --> True:
#                           Predict {'1': 1}
#                         --> False:
#                           Is home/away == 760.0?
#                           --> True:
#                             Predict {'1': 1}
#                           --> False:
#                             Is home/away == 125.0?
#                             --> True:
#                               Predict {'1': 1}
#                             --> False:
#                               Is home/away == 564.0?
#                               --> True:
#                                 Predict {'1': 1}
#                               --> False:
#                                 Is home/away == 206.0?
#                                 --> True:
#                                   Predict {'1': 1}
#                                 --> False:
#                                   Is home/away == 499.0?
#                                   --> True:
#                                     Predict {'1': 1}
#                                   --> False:
#                                     Is home/away == 355.0?
#                                     --> True:
#                                       Predict {'1': 1}
#                                     --> False:
#                                       Is home/away == 546.0?
#                                       --> True:
#                                         Predict {'1': 1}
#                                       --> False:
#                                         Is home/away == 401.0?
#                                         --> True:
#                                           Predict {'1': 1}
#                                         --> False:
#                                           Is home/away == 653.0?
#                                           --> True:
#                                             Predict {'1': 1}
#                                           --> False:
#                                             Is home/away == 734.0?
#                                             --> True:
#                                               Predict {'1': 1}
#                                             --> False:
#                                               Is home/away == 420.0?
#                                               --> True:
#                                                 Predict {'1': 1}
#                                               --> False:
#                                                 Is home/away == 756.0?
#                                                 --> True:
#                                                   Predict {'1': 1}
#                                                 --> False:
#                                                   Is home/away == 750.0?
#                                                   --> True:
#                                                     Predict {'1': 1}
#                                                   --> False:
#                                                     Is home/away == 303.0?
#                                                     --> True:
#                                                       Predict {'1': 1}
#                                                     --> False:
#                                                       Is home/away == 705.0?
#                                                       --> True:
#                                                         Predict {'1': 1}
#                                                       --> False:
#                                                         Is home/away == 741.0?
#                                                         --> True:
#                                                           Predict {'1': 1}
#                                                         --> False:
#                                                           Is home/away == 417.0?
#                                                           --> True:
#                                                             Predict {'1': 1}
#                                                           --> False:
#                                                             Is home/away == 609.0?
#                                                             --> True:
#                                                               Predict {'1': 1}
#                                                             --> False:
#                                                               Is home/away == 603.0?
#                                                               --> True:
#                                                                 Predict {'1': 1}
#                                                               --> False:
#                                                                 Is home/away == 204.0?
#                                                                 --> True:
#                                                                   Predict {'1': 1}
#                                                                 --> False:
#                                                                   Is home/away == 752.0?
#                                                                   --> True:
#                                                                     Predict {'1': 1}
#                                                                   --> False:
#                                                                     Is home/away == 745.0?
#                                                                     --> True:
#                                                                       Predict {'1': 1}
#                                                                     --> False:
#                                                                       Is home/away == 388.0?
#                                                                       --> True:
#                                                                         Predict {'1': 1}
#                                                                       --> False:
#                                                                         Is home/away == 121.0?
#                                                                         --> True:
#                                                                           Predict {'1': 1}
#                                                                         --> False:
#                                                                           Is home/away == 746.0?
#                                                                           --> True:
#                                                                             Predict {'1': 1}
#                                                                           --> False:
#                                                                             Is home/away == 322.0?
#                                                                             --> True:
#                                                                               Predict {'1': 1}
#                                                                             --> False:
#                                                                               Is home/away == 747.0?
#                                                                               --> True:
#                                                                                 Predict {'1': 1}
#                                                                               --> False:
#                                                                                 Is home/away == 574.0?
#                                                                                 --> True:
#                                                                                   Predict {'1': 1}
#                                                                                 --> False:
#                                                                                   Is home/away == 210.0?
#                                                                                   --> True:
#                                                                                     Predict {'1': 1}
#                                                                                   --> False:
#                                                                                     Is home/away == 602.0?
#                                                                                     --> True:
#                                                                                       Predict {'1': 1}
#                                                                                     --> False:
#                                                                                       Is home/away == 500.0?
#                                                                                       --> True:
#                                                                                         Predict {'1': 1}
#                                                                                       --> False:
#                                                                                         Is home/away == 742.0?
#                                                                                         --> True:
#                                                                                           Predict {'1': 1}
#                                                                                         --> False:
#                                                                                           Is home/away == 446.0?
#                                                                                           --> True:
#                                                                                             Predict {'1': 1}
#                                                                                           --> False:
#                                                                                             Is home/away == 423.0?
#                                                                                             --> True:
#                                                                                               Predict {'1': 1}
# ...
#                                                                                   --> True:
#                                                                                     Predict {'0': 1}
#                                                                                   --> False:
#                                                                                     Is home/away == 590.0?
#                                                                                     --> True:
#                                                                                       Predict {'0': 1}
#                                                                                     --> False:
#                                                                                       Is home/away == 553.0?
#                                                                                       --> True:
#                                                                                         Predict {'0': 1}
#                                                                                       --> False:
#                                                                                         Is home/away == 723.0?
#                                                                                         --> True:
#                                                                                           Predict {'0': 1}
#                                                                                         --> False:
#                                                                                           Is home/away == 664.0?
#                                                                                           --> True:
#                                                                                             Predict {'0': 1}
#                                                                                           --> False:
#                                                                                             Is home/away == 196.0?
#                                                                                             --> True:
#                                                                                               Predict {'0': 1}
#                                                                                             --> False:
#                                                                                               Is home/away == 310.0?
#                                                                                               --> True:
#                                                                                                 Predict {'0': 1}
#                                                                                               --> False:
#                                                                                                 Is home/away == 555.0?
#                                                                                                 --> True:
#                                                                                                   Predict {'0': 1}
#                                                                                                 --> False:
#                                                                                                   Is home/away == 668.0?
#                                                                                                   --> True:
#                                                                                                     Predict {'0': 1}
#                                                                                                   --> False:
#                                                                                                     Is home/away == 323.0?
#                                                                                                     --> True:
#                                                                                                       Predict {'0': 1}
#                                                                                                     --> False:
#                                                                                                       Is home/away == 235.0?
#                                                                                                       --> True:
#                                                                                                         Predict {'0': 1}
#                                                                                                       --> False:
#                                                                                                         Is home/away == 217.0?
#                                                                                                         --> True:
#                                                                                                           Predict {'0': 1}
#                                                                                                         --> False:
#                                                                                                           Is home/away == 181.0?
#                                                                                                           --> True:
#                                                                                                             Predict {'0': 1}
#                                                                                                           --> False:
#                                                                                                             Is home/away == 678.0?
#                                                                                                             --> True:
#                                                                                                               Predict {'0': 1}
#                                                                                                             --> False:
#                                                                                                               Is home/away == 366.0?
#                                                                                                               --> True:
#                                                                                                                 Predict {'0': 1}
#                                                                                                               --> False:
#                                                                                                                 Is home/away == 408.0?
#                                                                                                                 --> True:
#                                                                                                                   Predict {'0': 1}
#                                                                                                                 --> False:
#                                                                                                                   Is home/away == 215.0?
#                                                                                                                   --> True:
#                                                                                                                     Predict {'0': 1}
#                                                                                                                   --> False:
#                                                                                                                     Is home/away == 701.0?
#                                                                                                                     --> True:
#                                                                                                                       Predict {'0': 1}
#                                                                                                                     --> False:
#                                                                                                                       Is home/away == 780.0?
#                                                                                                                       --> True:
#                                                                                                                         Predict {'0': 1}
#                                                                                                                       --> False:
#                                                                                                                         Is home/away == 795.0?
#                                                                                                                         --> True:
#                                                                                                                           Predict {'0': 1}
#                                                                                                                         --> False:
#                                                                                                                           Is home/away == 531.0?
#                                                                                                                           --> True:
#                                                                                                                             Predict {'0': 1}
#                                                                                                                           --> False:
#                                                                                                                             Is home/away == 777.0?
#                                                                                                                             --> True:
#                                                                                                                               Predict {'0': 1}
#                                                                                                                             --> False:
#                                                                                                                               Is home/away == 184.0?
#                                                                                                                               --> True:
#                                                                                                                                 Predict {'0': 1}
#                                                                                                                               --> False:
#                                                                                                                                 Is home/away == 627.0?
#                                                                                                                                 --> True:
#                                                                                                                                   Predict {'0': 1}
#                                                                                                                                 --> False:
#                                                                                                                                   Is home/away == 611.0?
#                                                                                                                                   --> True:
#                                                                                                                                     Predict {'0': 1}
#                                                                                                                                   --> False:
#                                                                                                                                     Is home/away == 536.0?
#                                                                                                                                     --> True:
#                                                                                                                                       Predict {'0': 1}
#                                                                                                                                     --> False:
#                                                                                                                                       Is home/away == 768.0?
#                                                                                                                                       --> True:
#                                                                                                                                         Predict {'0': 1}
#                                                                                                                                       --> False:
#                                                                                                                                         Is home/away == 667.0?
#                                                                                                                                         --> True:
#                                                                                                                                           Predict {'0': 1}
#                                                                                                                                         --> False:
#                                                                                                                                           Is home/away == 459.0?
#                                                                                                                                           --> True:
#                                                                                                                                             Predict {'0': 1}
#                                                                                                                                           --> False:
#                                                                                                                                             Is home/away == 544.0?
#                                                                                                                                             --> True:
#                                                                                                                                               Predict {'0': 1}
#                                                                                                                                             --> False:
#                                                                                                                                               Is home/away == 201.0?
#                                                                                                                                               --> True:
#                                                                                                                                                 Predict {'0': 1}
#                                                                                                                                               --> False:
#                                                                                                                                                 Predict {'1': 82}
#   --> False:
#     Predict {'win': 2}

# %%
def classify(row, node):
    """See the 'rules of recursion' above."""

    # Base case: we've reached a leaf
    if isinstance(node, Leaf):
        return node.predictions

    # Decide whether to follow the true-branch or the false-branch.
    # Compare the feature / value stored in the node,
    # to the example we're considering.
    if node.question.match(row):
        return classify(row, node.true_branch)
    else:
        return classify(row, node.false_branch)

# %%
#######
# Demo:
# The tree predicts the 1st row of our
# training data is an apple with confidence 1.
classify(training_set[0], my_tree)
#######
# Out:
# {'win': 2}

# %%
def print_leaf(counts):
    """A nicer way to print the predictions at a leaf."""
    total = sum(counts.values()) * 1.0
    probs = {}
    for lbl in counts.keys():
        probs[lbl] = str(int(counts[lbl] / total * 100)) + "%"
    return probs

# %%
#######
# Demo:
# Printing that a bit nicer
print_leaf(classify(training_set[0], my_tree))
#######
# Out:
# {'win': '100%'}

# %%
print_leaf(classify(training_set[1], my_tree))
#######
# Out:
# {'win': '100%'}

# %%
testing_data=training_set[200:300]

# %%
for row in testing_data:
    print ("Actual: %s. Predicted: %s" %
           (row[-1], print_leaf(classify(row, my_tree))))
# Out:
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
# Actual: 0. Predicted: {'0': '100%'}
# Actual: 1. Predicted: {'1': '100%'}
